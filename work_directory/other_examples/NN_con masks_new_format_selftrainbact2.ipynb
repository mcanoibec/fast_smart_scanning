# %% [markdown]
# ## Neural network playing ground (Small Methods Imgs)
# ### Nov 2023 - Code by Mauricio Cano Galván

# %% [markdown]
# Library Import

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from copy import copy


from sklearn.metrics import r2_score, mean_absolute_error
from matplotlib import colormaps
from matplotlib.colors import ListedColormap
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import ShuffleSplit
from scipy.stats import norm
import seaborn as sns
import math
from tqdm import tqdm

from nn_backend.import_xyz_img import import_xyz_img
from nn_backend.conv_imgs import conv_imgs
from nn_backend.data_import import import_curves_from_folder, curve_calibration, matrix_cut, data_augment, mask_from_topo
from nn_backend.nn_for_ep import nn_for_ep
from nn_backend.post_process import img_export, histogram_export
from nn_backend.extras import simulation_table_import


viridis = colormaps['viridis']
newcolors = viridis(np.linspace(0, 1, 256))
black = np.array([0, 0, 0, 1])
newcolors[0:13, :] = black
newcmp = ListedColormap(newcolors)
del black, newcolors, viridis

# %%
#Program configuration

#Data import
name='newbact' #Filename with which to save exports
topography_file=rf'C:\Users\mcano\Code\rawdata\img_data\Bacterias_Ruben\Out_Get_10_EpOnpx_2024-10-16-10-7\FlattenTopo_.txt'
ref_file=rf"C:\Users\mcano\Code\rawdata\img_data\Bacterias_Ruben\Out_Get_10_EpOnpx_2024-10-16-10-7\Map_Ep.txt"
sim_tables_folder=rf'C:\Users\mcano\Code\rawdata\img_data\Bacterias_Ruben\Out_Get_10_EpOnpx_2024-10-16-10-7\tablas'
lift_imgs_folder=rf'C:\Users\mcano\Code\rawdata\img_data\Bacterias_Ruben\Out_Get_10_EpOnpx_2024-10-16-10-7\lifts'
raw_curves_folder=0
calibrate_curves=1
ref_flip=0
topo_flip=1


#Curve pre-processing
curves_max_limit=1000 #Maximum height [nm] to which the approximation curves will be projected
curve_nsamples=12 #Number of samples to take from approximation curves
curve_height_setpoint=20 #First curve height [nm] to take in consideration for sampling


#Optional graphics to show in notebook (1 to show images, 0 to hide)
input_imgs_view=1


#Neural Network Setup
pctg=90 #Percentage of train data
cutout_size=33 #Size of the topography cutouts for the convolution operation
kernel_dim=3 #Kernel dimension for the convolution operation
iterations=300
batch_sz=200 #Batch size for training

#Mask configuration. The following images should be processed using the values established.

    #EFM9: binary_threshold=0.04, object_size=3, hole_size=30, m_thresh=0.30
    #EFM8: binary_threshold=0.41, object_size=3, hole_size=30, m_thresh=0.77
    #EFM7: binary_threshold=0.095, object_size=4, hole_size=15, m_thresh=0.44
    #EFVM: binary_threshold=0.05, object_size=2, hole_size=2, m_thresh=0.785
    #newbact: binary_threshold=0.067, object_size=3, hole_size=30, m_thresh=0.30
binary_threshold=0.067
object_size=3
hole_size=30
m_ep_thresh=0.30

# %% [markdown]
# Data Import

# %%
dimtest, x, y2 = import_xyz_img(topography_file)
og_dim=len(dimtest)

# %%
use_lift_files=1
if use_lift_files:
    lifts=[20,30,40,80,150]
    samples=lifts
    lift_samples=np.zeros((og_dim,og_dim,1))
    for l in lifts:
        file, ax_ep, ay_ep= import_xyz_img(rf'{lift_imgs_folder}\LiftPower_{l}_.txt')
        file=np.expand_dims(file,axis=-1)
        lift_samples=np.concatenate((lift_samples,file), axis=-1)
        
    lift_samples=lift_samples[:,:,1:]

# %%
#------Import the label data (εp map), as a matrix first and then transformed into a DataFrame.------#
#----------The data is then cleaned to remove outliers

nu_dim=og_dim-cutout_size+1

y_mat, ax_ep, ay_ep= import_xyz_img(ref_file)
if ref_flip:
    y_mat=np.flipud(y_mat)
y_mat=matrix_cut(y_mat,nu_dim)
y=pd.DataFrame(np.reshape(y_mat,nu_dim**2))


#Logarithmic sampling
zetas=np.arange(curves_max_limit)
maxlen=1713


zs=np.round((np.logspace(start=0,stop=math.log10(maxlen),num=curve_nsamples,endpoint=False)+curve_height_setpoint)).astype(int)
samples = []
[samples.append(x) for x in zs if x not in samples]


if use_lift_files:
    curves_sampled=matrix_cut(lift_samples, nu_dim)
    curves_sampled=curves_sampled.reshape(nu_dim*nu_dim,len(lifts))
    #curves_sampled=curves_sampled[:3]
    b=np.zeros((curves_max_limit,1))

    zzz=np.array(lifts)
    projection = np.full((len(curves_sampled),len(zetas)), np.nan)
    for h in tqdm(np.arange(len(curves_sampled))):
        ccc=curves_sampled[h,:]
        indices = np.where(np.isin(zetas, zzz.astype(int)))[0]
        projection[h, indices] = ccc[np.isin(np.round(zzz), zetas)]
    projection=pd.DataFrame(projection)
    projection=projection.interpolate(axis=1)
    projection=projection.bfill(axis=1)
    curves_sampled=np.array(projection).reshape(nu_dim,nu_dim,curves_max_limit)
    curves_sampled=curves_sampled[:,:,samples]
    
else:


    #New curves
    curves=(np.array(curves_projected)).reshape(og_dim,og_dim,len(curves_projected.iloc[0,:]))
    curves=matrix_cut(curves, nu_dim)
    curves_sampled=curves[:,:,samples]

#Topography import
T_mat, x, y2 = import_xyz_img(topography_file)
T_mat=matrix_cut(T_mat, nu_dim)
T_mat=np.expand_dims(T_mat, axis=2)
T=T_mat.reshape(nu_dim**2)
#Put together training dataset
X_mat=np.concatenate((T_mat, curves_sampled), axis=2)

aa=["Z = "+str(x)+" nm" for x in samples]
inputs=["Topography"]
inputs=np.append(inputs, aa)

X=np.reshape(X_mat,(nu_dim**2,len(X_mat[0,0,:])))
X=pd.DataFrame(X, columns=inputs)


plt.subplot(1,2,1)
plt.imshow(T_mat, cmap='hot')
plt.title('Topography')
plt.axis('off')
plt.subplot(1,2,2)
plt.imshow(y_mat, cmap=newcmp, vmin=-1, vmax=8)
plt.title('$ε_p$ map')
plt.axis('off')
# Out:
# 100%|██████████| 50176/50176 [00:08<00:00, 5924.59it/s]
# (-0.5, 223.5, 223.5, -0.5)

# %%
if input_imgs_view:
    fig=plt.figure(figsize=(12,10))
    ax=fig.add_subplot(5,3,1)
    pcm=ax.imshow(X_mat[:,:,0], cmap='hot')
    ax.set_title("Topography")
    plt.colorbar(pcm, label="nm")
    ax.axis('off')
    for i in range(2,len(X.iloc[0])+1):
        ax=fig.add_subplot(5,3,i)
        pcm=ax.imshow(X_mat[:,:,i-1], cmap='hot', vmin=0.0, vmax=0.015)
        h=samples[i-2]
        ax.set_title("Lift; Z = "+str(h)+" nm")
        plt.colorbar(pcm, label="$dC/dz$")
        ax.axis('off')

# %% [markdown]
# Data Pre-Processing

# %%
binary_threshold=0.9905
object_size=3
hole_size=30
m_ep_thresh=0.30

masker=abs(1-X.iloc[:,1])

bin=mask_from_topo(masker,binary_threshold,object_size,hole_size)

cell=bin.reshape(nu_dim**2,1)
roi_index=pd.DataFrame(copy(cell))
roi_index=roi_index.index[(roi_index[0])]


mask_ep=pd.DataFrame(copy(y))
th=float(mask_ep.quantile(m_ep_thresh))

mask_ep[(mask_ep[0]<=th)]=0
mask_ep[(mask_ep[0]!=0)]=1
mask_ep=cell*mask_ep
mask_ep_im=np.reshape(np.array(mask_ep), ((nu_dim),(nu_dim)))

cell_index=mask_ep.index[mask_ep[0]>0].tolist()


fig=plt.figure(figsize=(10,7))
ax=fig.add_subplot(1,2,1)
ax.imshow(bin, cmap='gray')
ax.set_title('ROI mask')
ax.axis('off')
ax=fig.add_subplot(1,2,2)
ax.imshow(mask_ep_im)
ax.axis('off')
ax.set_title('Final Train Mask')
# Out:
# C:\Users\mcano\AppData\Local\Temp\ipykernel_18972\4288235065.py:16: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   th=float(mask_ep.quantile(m_ep_thresh))
# Text(0.5, 1.0, 'Final Train Mask')

# %%
plt.hist(masker)
plt.imshow(np.array(masker).reshape(224,224))

# %%
#------Cell separation------#
y_cell=pd.DataFrame(y.iloc[cell_index])
X_cell=pd.DataFrame(X.iloc[cell_index])
y_roi=pd.DataFrame(y.iloc[roi_index])
X_roi=pd.DataFrame(X.iloc[roi_index])


#------Data Normalization------#
curve_scale=StandardScaler()
curve_scale.fit(X_cell)
Xn_cell=pd.DataFrame(curve_scale.transform(X_cell), columns=inputs)
Xn_roi=pd.DataFrame(curve_scale.transform(X_roi), columns=inputs)

# %%
#------Data Normalization------#
curve_scale=StandardScaler()
curve_scale.fit(X_cell)
Xn_cell=pd.DataFrame(curve_scale.transform(X_cell), columns=inputs)

# %%
topo_mat, x, y2 = import_xyz_img(topography_file)
topo=topo_mat.reshape(len(topo_mat)**2,1)

topo_scale=StandardScaler()
topo_scale.fit(topo)
topo_n=topo_scale.transform(topo)
topo_n_mat=topo_n.reshape(len(topo_mat),len(topo_mat),1)

# %%
full_cutouts=0

if full_cutouts:
    Cv_mat=conv_imgs(topo_n_mat[:,:,0], cutout_size)
    Cv_mat=Cv_mat.reshape(int(math.sqrt(len(Cv_mat))),int(math.sqrt(len(Cv_mat))),cutout_size,cutout_size)
    Cv_mat=matrix_cut(Cv_mat, nu_dim)

    Cv_mat=Cv_mat.reshape(nu_dim*nu_dim,cutout_size,cutout_size)
    Cv_mat=np.expand_dims(Cv_mat, axis=-1)

    Cv_mat=Cv_mat.reshape(nu_dim*nu_dim,cutout_size,cutout_size)
    Cv_mat=np.expand_dims(Cv_mat, axis=-1)
    Cv_cell_mat=Cv_mat[cell_index,:,:,:]
    Cv_roi_mat=Cv_mat[roi_index,:,:,:]
    # Cv_tab_mat=Cv_mat[tab_index,:,:,:]
else:
    y_coord, x_coord= np.unravel_index(cell_index, (nu_dim, nu_dim))
    cell_index_2=np.transpose(np.column_stack((y_coord, x_coord)))
    cell_index_2[0]=cell_index_2[0]+int((cutout_size-1)/2)
    cell_index_2[1]=cell_index_2[1]+int((cutout_size-1)/2)

    y_coord, x_coord= np.unravel_index(roi_index, (nu_dim, nu_dim))
    roi_index_2=np.transpose(np.column_stack((y_coord, x_coord)))
    roi_index_2[0]=roi_index_2[0]+int((cutout_size-1)/2)
    roi_index_2[1]=roi_index_2[1]+int((cutout_size-1)/2)


    Cv_cell_mat=conv_imgs(topo_n_mat[:,:,0], cutout_size, cell_index_2)
    Cv_roi_mat=conv_imgs(topo_n_mat[:,:,0], cutout_size, roi_index_2)
    Cv_cell_mat=np.expand_dims(Cv_cell_mat, axis=-1)
    Cv_roi_mat=np.expand_dims(Cv_roi_mat, axis=-1)
# Out:
# 100%|██████████| 278/278 [00:00<00:00, 2172.56it/s]
# 100%|██████████| 4186/4186 [00:21<00:00, 191.26it/s]

# %%
Xn_train_input=Xn_cell
y_train_input=y_cell
Cv_train_input=Cv_cell_mat
train_input_index=cell_index

# Xn_train_input=Xn_tab
# y_train_input=y_tab
# Cv_train_input=Cv_tab_mat
# train_input_index=tab_index

# %% [markdown]
# Test-Train Separation

# %%
pctg=50
sss = ShuffleSplit(n_splits=1, test_size=1-(pctg/100), random_state=1)
sss.get_n_splits(Xn_train_input, y_train_input)
train_index, test_index = next(sss.split(Xn_train_input, y_train_input))
train_index=np.sort(train_index)  
test_index=np.sort(test_index)  



X_train, X_test = Xn_train_input.iloc[train_index], Xn_train_input.iloc[test_index] 
y_train, y_test = y_train_input.iloc[train_index], y_train_input.iloc[test_index]

Cv_train, Cv_test = Cv_train_input[train_index,:,:], Cv_train_input[test_index,:,:] 
Cv_train_aug=data_augment(Cv_train)


N_aug=int(len(Cv_train_aug[:,0,0,0])/len(Cv_train[:,0,0,0]))

X_train_aug=copy(X_train)
y_train_aug=copy(y_train)
for i in np.arange(N_aug-1):
    X_train_aug=pd.DataFrame(np.concatenate((X_train_aug, X_train), axis=0))
    y_train_aug=pd.DataFrame(np.concatenate((y_train_aug, y_train), axis=0))

# %% [markdown]
# Network Architecture

# %%
#------Example Keras Network------#
reg, histo=nn_for_ep(X_train_aug,Cv_train_aug,y_train_aug,X_test,Cv_test,y_test, verb=1)
# Out:
# Epoch 1/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 3.2822 - mae: 8.3215 - val_loss: 0.7180 - val_mae: 9.7030
# Epoch 2/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.7793 - mae: 9.4775 - val_loss: 0.3697 - val_mae: 4.9467
# Epoch 3/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.4144 - mae: 5.1603 - val_loss: 0.3166 - val_mae: 4.8860
# Epoch 4/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.3989 - mae: 5.4316 - val_loss: 0.3117 - val_mae: 4.7790
# Epoch 5/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.3768 - mae: 5.0481 - val_loss: 0.3191 - val_mae: 4.7773
# Epoch 6/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.3705 - mae: 4.9566 - val_loss: 0.3067 - val_mae: 4.7693
# Epoch 7/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.3690 - mae: 4.9912 - val_loss: 0.3118 - val_mae: 4.7719
# Epoch 8/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.3597 - mae: 4.8426 - val_loss: 0.2963 - val_mae: 4.7046
# Epoch 9/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.3528 - mae: 4.8499 - val_loss: 0.2938 - val_mae: 4.6983
# Epoch 10/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.3428 - mae: 4.7695 - val_loss: 0.2820 - val_mae: 4.6404
# Epoch 11/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.3310 - mae: 4.7063 - val_loss: 0.2718 - val_mae: 4.5900
# Epoch 12/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.3179 - mae: 4.6484 - val_loss: 0.2650 - val_mae: 4.5531
# Epoch 13/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.3002 - mae: 4.5063 - val_loss: 0.2545 - val_mae: 4.4911
# Epoch 14/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.2775 - mae: 4.3518 - val_loss: 0.2389 - val_mae: 4.4056
# Epoch 15/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.2504 - mae: 4.2219 - val_loss: 0.2309 - val_mae: 4.4465
# Epoch 16/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.2298 - mae: 4.1812 - val_loss: 0.2373 - val_mae: 4.5848
# Epoch 17/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.2105 - mae: 4.0505 - val_loss: 0.2360 - val_mae: 4.5874
# Epoch 18/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.1843 - mae: 3.8103 - val_loss: 0.2429 - val_mae: 4.6561
# Epoch 19/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.1680 - mae: 3.6874 - val_loss: 0.2242 - val_mae: 4.4854
# Epoch 20/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.1368 - mae: 3.3711 - val_loss: 0.2425 - val_mae: 4.6306
# Epoch 21/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.1317 - mae: 3.2999 - val_loss: 0.2405 - val_mae: 4.5815
# Epoch 22/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.1151 - mae: 3.0911 - val_loss: 0.2837 - val_mae: 4.9501
# Epoch 23/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.1324 - mae: 3.2710 - val_loss: 0.3231 - val_mae: 5.3604
# Epoch 24/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.1719 - mae: 3.6935 - val_loss: 0.2847 - val_mae: 4.9520
# Epoch 25/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.2291 - mae: 4.3860 - val_loss: 0.4870 - val_mae: 5.5822
# Epoch 26/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.2954 - mae: 4.5663 - val_loss: 0.2622 - val_mae: 4.5569
# Epoch 27/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.2183 - mae: 3.9727 - val_loss: 0.2652 - val_mae: 4.4798
# Epoch 28/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.1605 - mae: 3.5318 - val_loss: 0.2182 - val_mae: 4.2934
# Epoch 29/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0839 - mae: 2.6023 - val_loss: 0.2390 - val_mae: 4.2018
# Epoch 30/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.1376 - mae: 3.1995 - val_loss: 0.2405 - val_mae: 4.2025
# Epoch 31/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.1252 - mae: 3.1338 - val_loss: 0.2098 - val_mae: 4.2007
# Epoch 32/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0843 - mae: 2.4969 - val_loss: 0.2341 - val_mae: 4.1903
# Epoch 33/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0897 - mae: 2.7442 - val_loss: 0.2060 - val_mae: 4.1890
# Epoch 34/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0512 - mae: 2.0338 - val_loss: 0.2159 - val_mae: 4.0731
# Epoch 35/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0600 - mae: 2.1994 - val_loss: 0.2031 - val_mae: 4.0511
# Epoch 36/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0477 - mae: 2.0089 - val_loss: 0.2035 - val_mae: 4.1341
# Epoch 37/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0385 - mae: 1.7521 - val_loss: 0.2102 - val_mae: 4.0660
# Epoch 38/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0398 - mae: 1.8250 - val_loss: 0.2029 - val_mae: 4.1408
# Epoch 39/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0292 - mae: 1.5493 - val_loss: 0.2057 - val_mae: 4.1155
# Epoch 40/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0274 - mae: 1.4791 - val_loss: 0.2087 - val_mae: 4.0954
# Epoch 41/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0256 - mae: 1.4393 - val_loss: 0.2070 - val_mae: 4.1450
# Epoch 42/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0207 - mae: 1.2798 - val_loss: 0.2087 - val_mae: 4.1382
# Epoch 43/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0185 - mae: 1.1998 - val_loss: 0.2116 - val_mae: 4.1152
# Epoch 44/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0174 - mae: 1.1708 - val_loss: 0.2118 - val_mae: 4.1372
# Epoch 45/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0150 - mae: 1.0845 - val_loss: 0.2119 - val_mae: 4.1682
# Epoch 46/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0129 - mae: 0.9827 - val_loss: 0.2119 - val_mae: 4.1535
# Epoch 47/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0115 - mae: 0.9227 - val_loss: 0.2145 - val_mae: 4.1397
# Epoch 48/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0107 - mae: 0.9040 - val_loss: 0.2152 - val_mae: 4.1466
# Epoch 49/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0096 - mae: 0.8656 - val_loss: 0.2136 - val_mae: 4.1653
# Epoch 50/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0081 - mae: 0.7786 - val_loss: 0.2134 - val_mae: 4.1961
# Epoch 51/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 0.0073 - mae: 0.7160 - val_loss: 0.2143 - val_mae: 4.1935
# Epoch 52/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0066 - mae: 0.6832 - val_loss: 0.2161 - val_mae: 4.1604
# Epoch 53/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0061 - mae: 0.6840 - val_loss: 0.2199 - val_mae: 4.1449
# Epoch 54/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0072 - mae: 0.7961 - val_loss: 0.2189 - val_mae: 4.1522
# Epoch 55/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0073 - mae: 0.8172 - val_loss: 0.2138 - val_mae: 4.1982
# Epoch 56/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 0.0060 - mae: 0.6957 - val_loss: 0.2200 - val_mae: 4.3863
# Epoch 57/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0108 - mae: 0.9395 - val_loss: 0.2188 - val_mae: 4.3661
# Epoch 58/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0137 - mae: 1.0667 - val_loss: 0.2151 - val_mae: 4.1176
# Epoch 59/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0109 - mae: 0.9561 - val_loss: 0.2555 - val_mae: 4.2263
# Epoch 60/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0290 - mae: 1.6055 - val_loss: 0.2199 - val_mae: 4.1190
# Epoch 61/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0205 - mae: 1.3458 - val_loss: 0.2280 - val_mae: 4.5021
# Epoch 62/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0209 - mae: 1.2864 - val_loss: 0.2098 - val_mae: 4.2745
# Epoch 63/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0160 - mae: 1.1226 - val_loss: 0.2300 - val_mae: 4.1578
# Epoch 64/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0142 - mae: 1.1120 - val_loss: 0.2160 - val_mae: 4.1344
# Epoch 65/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0098 - mae: 0.9635 - val_loss: 0.2219 - val_mae: 4.3727
# Epoch 66/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0090 - mae: 0.8331 - val_loss: 0.2118 - val_mae: 4.1994
# Epoch 67/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0043 - mae: 0.5812 - val_loss: 0.2214 - val_mae: 4.1769
# Epoch 68/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0062 - mae: 0.7396 - val_loss: 0.2153 - val_mae: 4.2687
# Epoch 69/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0032 - mae: 0.5009 - val_loss: 0.2183 - val_mae: 4.3224
# Epoch 70/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0040 - mae: 0.5827 - val_loss: 0.2162 - val_mae: 4.1943
# Epoch 71/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0025 - mae: 0.4596 - val_loss: 0.2168 - val_mae: 4.1844
# Epoch 72/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0029 - mae: 0.5220 - val_loss: 0.2161 - val_mae: 4.2866
# Epoch 73/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0020 - mae: 0.4087 - val_loss: 0.2164 - val_mae: 4.2884
# Epoch 74/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0022 - mae: 0.4341 - val_loss: 0.2160 - val_mae: 4.2022
# Epoch 75/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0017 - mae: 0.3793 - val_loss: 0.2170 - val_mae: 4.2018
# Epoch 76/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0018 - mae: 0.4124 - val_loss: 0.2166 - val_mae: 4.2792
# Epoch 77/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0013 - mae: 0.3251 - val_loss: 0.2162 - val_mae: 4.2914
# Epoch 78/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0014 - mae: 0.3535 - val_loss: 0.2153 - val_mae: 4.2224
# Epoch 79/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0011 - mae: 0.2910 - val_loss: 0.2172 - val_mae: 4.2112
# Epoch 80/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0013 - mae: 0.3374 - val_loss: 0.2166 - val_mae: 4.2628
# Epoch 81/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 8.5061e-04 - mae: 0.2493 - val_loss: 0.2161 - val_mae: 4.2911
# Epoch 82/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 9.7338e-04 - mae: 0.2848 - val_loss: 0.2150 - val_mae: 4.2556
# Epoch 83/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 7.2575e-04 - mae: 0.2263 - val_loss: 0.2167 - val_mae: 4.2276
# Epoch 84/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 7.7531e-04 - mae: 0.2473 - val_loss: 0.2172 - val_mae: 4.2427
# Epoch 85/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 6.8321e-04 - mae: 0.2279 - val_loss: 0.2162 - val_mae: 4.2738
# Epoch 86/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 5.7461e-04 - mae: 0.1969 - val_loss: 0.2155 - val_mae: 4.2819
# Epoch 87/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 6.3338e-04 - mae: 0.2185 - val_loss: 0.2157 - val_mae: 4.2627
# Epoch 88/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 5.0842e-04 - mae: 0.1793 - val_loss: 0.2170 - val_mae: 4.2420
# Epoch 89/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 5.3730e-04 - mae: 0.1935 - val_loss: 0.2173 - val_mae: 4.2430
# Epoch 90/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 5.7940e-04 - mae: 0.2111 - val_loss: 0.2163 - val_mae: 4.2664
# Epoch 91/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 4.6149e-04 - mae: 0.1669 - val_loss: 0.2160 - val_mae: 4.2928
# Epoch 92/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 5.9476e-04 - mae: 0.2162 - val_loss: 0.2159 - val_mae: 4.2878
# Epoch 93/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 6.3850e-04 - mae: 0.2291 - val_loss: 0.2164 - val_mae: 4.2525
# Epoch 94/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 5.0943e-04 - mae: 0.1871 - val_loss: 0.2184 - val_mae: 4.2304
# Epoch 95/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 8.8800e-04 - mae: 0.2816 - val_loss: 0.2180 - val_mae: 4.2428
# Epoch 96/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 8.9482e-04 - mae: 0.2828 - val_loss: 0.2163 - val_mae: 4.2900
# Epoch 97/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 7.2931e-04 - mae: 0.2436 - val_loss: 0.2169 - val_mae: 4.3428
# Epoch 98/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0017 - mae: 0.4104 - val_loss: 0.2158 - val_mae: 4.3117
# Epoch 99/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0018 - mae: 0.4093 - val_loss: 0.2172 - val_mae: 4.2247
# Epoch 100/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0015 - mae: 0.3589 - val_loss: 0.2255 - val_mae: 4.2084
# Epoch 101/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0043 - mae: 0.6478 - val_loss: 0.2210 - val_mae: 4.2251
# Epoch 102/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0039 - mae: 0.6065 - val_loss: 0.2170 - val_mae: 4.3480
# Epoch 103/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0035 - mae: 0.5693 - val_loss: 0.2265 - val_mae: 4.5300
# Epoch 104/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0097 - mae: 0.9975 - val_loss: 0.2157 - val_mae: 4.3387
# Epoch 105/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0088 - mae: 0.8818 - val_loss: 0.2265 - val_mae: 4.1719
# Epoch 106/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0099 - mae: 0.9273 - val_loss: 0.2480 - val_mae: 4.2388
# Epoch 107/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0202 - mae: 1.3611 - val_loss: 0.2132 - val_mae: 4.2373
# Epoch 108/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0098 - mae: 0.8328 - val_loss: 0.2339 - val_mae: 4.6386
# Epoch 109/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0171 - mae: 1.2623 - val_loss: 0.2127 - val_mae: 4.3276
# Epoch 110/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0128 - mae: 1.0465 - val_loss: 0.2317 - val_mae: 4.1692
# Epoch 111/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0119 - mae: 1.0428 - val_loss: 0.2236 - val_mae: 4.1814
# Epoch 112/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0094 - mae: 0.9277 - val_loss: 0.2193 - val_mae: 4.3559
# Epoch 113/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0068 - mae: 0.7644 - val_loss: 0.2139 - val_mae: 4.3051
# Epoch 114/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0048 - mae: 0.6600 - val_loss: 0.2200 - val_mae: 4.1875
# Epoch 115/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0043 - mae: 0.6055 - val_loss: 0.2170 - val_mae: 4.2147
# Epoch 116/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0025 - mae: 0.4836 - val_loss: 0.2189 - val_mae: 4.3511
# Epoch 117/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0030 - mae: 0.5252 - val_loss: 0.2138 - val_mae: 4.2476
# Epoch 118/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0014 - mae: 0.3262 - val_loss: 0.2177 - val_mae: 4.1818
# Epoch 119/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0023 - mae: 0.4631 - val_loss: 0.2146 - val_mae: 4.2684
# Epoch 120/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 9.2810e-04 - mae: 0.2668 - val_loss: 0.2174 - val_mae: 4.3265
# Epoch 121/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0018 - mae: 0.4233 - val_loss: 0.2152 - val_mae: 4.2241
# Epoch 122/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 8.1962e-04 - mae: 0.2563 - val_loss: 0.2159 - val_mae: 4.2035
# Epoch 123/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0013 - mae: 0.3471 - val_loss: 0.2151 - val_mae: 4.2846
# Epoch 124/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 6.5532e-04 - mae: 0.2390 - val_loss: 0.2157 - val_mae: 4.2903
# Epoch 125/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 8.8772e-04 - mae: 0.2932 - val_loss: 0.2150 - val_mae: 4.2230
# Epoch 126/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 5.2179e-04 - mae: 0.2027 - val_loss: 0.2154 - val_mae: 4.2238
# Epoch 127/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 6.2272e-04 - mae: 0.2323 - val_loss: 0.2155 - val_mae: 4.2829
# Epoch 128/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 4.2282e-04 - mae: 0.1901 - val_loss: 0.2153 - val_mae: 4.2774
# Epoch 129/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 4.7488e-04 - mae: 0.2065 - val_loss: 0.2148 - val_mae: 4.2293
# Epoch 130/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 3.5236e-04 - mae: 0.1630 - val_loss: 0.2152 - val_mae: 4.2357
# Epoch 131/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 3.6607e-04 - mae: 0.1714 - val_loss: 0.2154 - val_mae: 4.2773
# Epoch 132/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 2.9342e-04 - mae: 0.1529 - val_loss: 0.2151 - val_mae: 4.2716
# Epoch 133/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 3.1225e-04 - mae: 0.1607 - val_loss: 0.2148 - val_mae: 4.2373
# Epoch 134/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 2.4473e-04 - mae: 0.1284 - val_loss: 0.2153 - val_mae: 4.2417
# Epoch 135/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 2.6118e-04 - mae: 0.1404 - val_loss: 0.2154 - val_mae: 4.2716
# Epoch 136/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 2.0575e-04 - mae: 0.1187 - val_loss: 0.2151 - val_mae: 4.2712
# Epoch 137/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 2.3374e-04 - mae: 0.1346 - val_loss: 0.2148 - val_mae: 4.2458
# Epoch 138/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 1.7392e-04 - mae: 0.0979 - val_loss: 0.2154 - val_mae: 4.2443
# Epoch 139/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 2.0323e-04 - mae: 0.1191 - val_loss: 0.2154 - val_mae: 4.2654
# Epoch 140/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 1.5011e-04 - mae: 0.0884 - val_loss: 0.2151 - val_mae: 4.2715
# Epoch 141/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 1.8245e-04 - mae: 0.1138 - val_loss: 0.2148 - val_mae: 4.2548
# Epoch 142/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 1.3510e-04 - mae: 0.0752 - val_loss: 0.2153 - val_mae: 4.2473
# Epoch 143/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 1.5620e-04 - mae: 0.0981 - val_loss: 0.2155 - val_mae: 4.2593
# Epoch 144/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 1.2494e-04 - mae: 0.0745 - val_loss: 0.2152 - val_mae: 4.2697
# Epoch 145/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.3414e-04 - mae: 0.0891 - val_loss: 0.2149 - val_mae: 4.2637
# Epoch 146/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 1.2268e-04 - mae: 0.0799 - val_loss: 0.2151 - val_mae: 4.2529
# Epoch 147/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 1.1184e-04 - mae: 0.0699 - val_loss: 0.2155 - val_mae: 4.2543
# Epoch 148/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 1.1719e-04 - mae: 0.0789 - val_loss: 0.2154 - val_mae: 4.2639
# Epoch 149/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 9.8455e-05 - mae: 0.0609 - val_loss: 0.2151 - val_mae: 4.2686
# Epoch 150/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.0880e-04 - mae: 0.0774 - val_loss: 0.2150 - val_mae: 4.2628
# Epoch 151/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 9.7968e-05 - mae: 0.0652 - val_loss: 0.2153 - val_mae: 4.2554
# Epoch 152/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 9.3711e-05 - mae: 0.0623 - val_loss: 0.2156 - val_mae: 4.2559
# Epoch 153/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 1.0199e-04 - mae: 0.0743 - val_loss: 0.2154 - val_mae: 4.2636
# Epoch 154/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 8.6029e-05 - mae: 0.0564 - val_loss: 0.2151 - val_mae: 4.2701
# Epoch 155/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 9.9783e-05 - mae: 0.0772 - val_loss: 0.2150 - val_mae: 4.2666
# Epoch 156/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 1.0062e-04 - mae: 0.0780 - val_loss: 0.2152 - val_mae: 4.2568
# Epoch 157/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 8.7595e-05 - mae: 0.0642 - val_loss: 0.2157 - val_mae: 4.2531
# Epoch 158/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 1.1981e-04 - mae: 0.0934 - val_loss: 0.2156 - val_mae: 4.2610
# Epoch 159/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 1.0134e-04 - mae: 0.0776 - val_loss: 0.2152 - val_mae: 4.2734
# Epoch 160/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 1.1197e-04 - mae: 0.0904 - val_loss: 0.2149 - val_mae: 4.2774
# Epoch 161/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 1.6641e-04 - mae: 0.1214 - val_loss: 0.2150 - val_mae: 4.2609
# Epoch 162/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 1.1934e-04 - mae: 0.0826 - val_loss: 0.2160 - val_mae: 4.2472
# Epoch 163/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 1.9699e-04 - mae: 0.1323 - val_loss: 0.2164 - val_mae: 4.2505
# Epoch 164/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 2.6947e-04 - mae: 0.1599 - val_loss: 0.2155 - val_mae: 4.2715
# Epoch 165/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 1.7715e-04 - mae: 0.1163 - val_loss: 0.2152 - val_mae: 4.3022
# Epoch 166/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 4.3861e-04 - mae: 0.2135 - val_loss: 0.2146 - val_mae: 4.2895
# Epoch 167/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 5.2825e-04 - mae: 0.2312 - val_loss: 0.2154 - val_mae: 4.2446
# Epoch 168/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 3.8997e-04 - mae: 0.1861 - val_loss: 0.2191 - val_mae: 4.2283
# Epoch 169/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0012 - mae: 0.3544 - val_loss: 0.2177 - val_mae: 4.2442
# Epoch 170/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0012 - mae: 0.3350 - val_loss: 0.2155 - val_mae: 4.3135
# Epoch 171/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0011 - mae: 0.3217 - val_loss: 0.2179 - val_mae: 4.3915
# Epoch 172/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0033 - mae: 0.5896 - val_loss: 0.2140 - val_mae: 4.3069
# Epoch 173/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0030 - mae: 0.5186 - val_loss: 0.2198 - val_mae: 4.2006
# Epoch 174/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0034 - mae: 0.5609 - val_loss: 0.2345 - val_mae: 4.2279
# Epoch 175/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0095 - mae: 0.9485 - val_loss: 0.2181 - val_mae: 4.2264
# Epoch 176/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0064 - mae: 0.7186 - val_loss: 0.2253 - val_mae: 4.5140
# Epoch 177/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0101 - mae: 0.9604 - val_loss: 0.2339 - val_mae: 4.6425
# Epoch 178/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0188 - mae: 1.3636 - val_loss: 0.2078 - val_mae: 4.1568
# Epoch 179/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0104 - mae: 0.8511 - val_loss: 0.2556 - val_mae: 4.2410
# Epoch 180/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0237 - mae: 1.4981 - val_loss: 0.2220 - val_mae: 4.1882
# Epoch 181/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.0153 - mae: 1.1499 - val_loss: 0.2346 - val_mae: 4.6160
# Epoch 182/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.0156 - mae: 1.1986 - val_loss: 0.2118 - val_mae: 4.3117
# Epoch 183/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0099 - mae: 0.9219 - val_loss: 0.2235 - val_mae: 4.1233
# Epoch 184/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0097 - mae: 0.9404 - val_loss: 0.2123 - val_mae: 4.1639
# Epoch 185/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0049 - mae: 0.6614 - val_loss: 0.2251 - val_mae: 4.4467
# Epoch 186/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0069 - mae: 0.8184 - val_loss: 0.2108 - val_mae: 4.2085
# Epoch 187/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0021 - mae: 0.3888 - val_loss: 0.2162 - val_mae: 4.1494
# Epoch 188/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0040 - mae: 0.6149 - val_loss: 0.2136 - val_mae: 4.3096
# Epoch 189/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0017 - mae: 0.3889 - val_loss: 0.2149 - val_mae: 4.2958
# Epoch 190/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - loss: 0.0021 - mae: 0.4416 - val_loss: 0.2157 - val_mae: 4.1789
# Epoch 191/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0017 - mae: 0.4155 - val_loss: 0.2122 - val_mae: 4.2304
# Epoch 192/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 9.4843e-04 - mae: 0.2600 - val_loss: 0.2146 - val_mae: 4.3065
# Epoch 193/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 9.3874e-04 - mae: 0.3251 - val_loss: 0.2137 - val_mae: 4.2358
# Epoch 194/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 4.7726e-04 - mae: 0.1913 - val_loss: 0.2131 - val_mae: 4.2147
# Epoch 195/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 4.2521e-04 - mae: 0.2087 - val_loss: 0.2129 - val_mae: 4.2689
# Epoch 196/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 2.4323e-04 - mae: 0.1469 - val_loss: 0.2133 - val_mae: 4.2622
# Epoch 197/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 1.7186e-04 - mae: 0.1248 - val_loss: 0.2131 - val_mae: 4.2320
# Epoch 198/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 1.3634e-04 - mae: 0.1090 - val_loss: 0.2130 - val_mae: 4.2438
# Epoch 199/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 8.0925e-05 - mae: 0.0750 - val_loss: 0.2134 - val_mae: 4.2619
# Epoch 200/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 7.6775e-05 - mae: 0.0830 - val_loss: 0.2132 - val_mae: 4.2489
# Epoch 201/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 5.0147e-05 - mae: 0.0534 - val_loss: 0.2130 - val_mae: 4.2415
# Epoch 202/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 4.7920e-05 - mae: 0.0580 - val_loss: 0.2132 - val_mae: 4.2539
# Epoch 203/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 3.7451e-05 - mae: 0.0457 - val_loss: 0.2134 - val_mae: 4.2579
# Epoch 204/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 3.5180e-05 - mae: 0.0467 - val_loss: 0.2131 - val_mae: 4.2475
# Epoch 205/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 3.0059e-05 - mae: 0.0366 - val_loss: 0.2132 - val_mae: 4.2485
# Epoch 206/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 2.7251e-05 - mae: 0.0352 - val_loss: 0.2134 - val_mae: 4.2555
# Epoch 207/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 2.4922e-05 - mae: 0.0334 - val_loss: 0.2133 - val_mae: 4.2540
# Epoch 208/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 2.2583e-05 - mae: 0.0291 - val_loss: 0.2132 - val_mae: 4.2502
# Epoch 209/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 2.1089e-05 - mae: 0.0277 - val_loss: 0.2133 - val_mae: 4.2527
# Epoch 210/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 1.9323e-05 - mae: 0.0251 - val_loss: 0.2134 - val_mae: 4.2553
# Epoch 211/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.8390e-05 - mae: 0.0256 - val_loss: 0.2133 - val_mae: 4.2535
# Epoch 212/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 1.6888e-05 - mae: 0.0221 - val_loss: 0.2133 - val_mae: 4.2522
# Epoch 213/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 1.5975e-05 - mae: 0.0220 - val_loss: 0.2134 - val_mae: 4.2541
# Epoch 214/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 1.4890e-05 - mae: 0.0203 - val_loss: 0.2134 - val_mae: 4.2552
# Epoch 215/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.4165e-05 - mae: 0.0204 - val_loss: 0.2134 - val_mae: 4.2541
# Epoch 216/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 1.3155e-05 - mae: 0.0181 - val_loss: 0.2134 - val_mae: 4.2537
# Epoch 217/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 1.2488e-05 - mae: 0.0180 - val_loss: 0.2134 - val_mae: 4.2549
# Epoch 218/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 1.1753e-05 - mae: 0.0170 - val_loss: 0.2134 - val_mae: 4.2554
# Epoch 219/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 1.1176e-05 - mae: 0.0168 - val_loss: 0.2134 - val_mae: 4.2547
# Epoch 220/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 1.0448e-05 - mae: 0.0153 - val_loss: 0.2135 - val_mae: 4.2545
# Epoch 221/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 9.9390e-06 - mae: 0.0152 - val_loss: 0.2135 - val_mae: 4.2553
# Epoch 222/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 9.3949e-06 - mae: 0.0145 - val_loss: 0.2135 - val_mae: 4.2558
# Epoch 223/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 8.9740e-06 - mae: 0.0144 - val_loss: 0.2135 - val_mae: 4.2554
# Epoch 224/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 8.4442e-06 - mae: 0.0133 - val_loss: 0.2135 - val_mae: 4.2551
# Epoch 225/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 8.0229e-06 - mae: 0.0131 - val_loss: 0.2135 - val_mae: 4.2555
# Epoch 226/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 7.5962e-06 - mae: 0.0124 - val_loss: 0.2135 - val_mae: 4.2561
# Epoch 227/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 7.2420e-06 - mae: 0.0123 - val_loss: 0.2135 - val_mae: 4.2558
# Epoch 228/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 6.8475e-06 - mae: 0.0116 - val_loss: 0.2135 - val_mae: 4.2554
# Epoch 229/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 6.4986e-06 - mae: 0.0112 - val_loss: 0.2135 - val_mae: 4.2557
# Epoch 230/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 6.1796e-06 - mae: 0.0109 - val_loss: 0.2135 - val_mae: 4.2562
# Epoch 231/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 5.8911e-06 - mae: 0.0106 - val_loss: 0.2135 - val_mae: 4.2561
# Epoch 232/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 5.6002e-06 - mae: 0.0102 - val_loss: 0.2135 - val_mae: 4.2558
# Epoch 233/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 5.3111e-06 - mae: 0.0098 - val_loss: 0.2135 - val_mae: 4.2558
# Epoch 234/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 5.0669e-06 - mae: 0.0096 - val_loss: 0.2135 - val_mae: 4.2562
# Epoch 235/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 4.8316e-06 - mae: 0.0092 - val_loss: 0.2135 - val_mae: 4.2562
# Epoch 236/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 4.6137e-06 - mae: 0.0090 - val_loss: 0.2135 - val_mae: 4.2560
# Epoch 237/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 4.3850e-06 - mae: 0.0086 - val_loss: 0.2135 - val_mae: 4.2559
# Epoch 238/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 4.1896e-06 - mae: 0.0084 - val_loss: 0.2135 - val_mae: 4.2561
# Epoch 239/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 4.0065e-06 - mae: 0.0081 - val_loss: 0.2135 - val_mae: 4.2562
# Epoch 240/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 3.8370e-06 - mae: 0.0079 - val_loss: 0.2135 - val_mae: 4.2562
# Epoch 241/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 3.6663e-06 - mae: 0.0077 - val_loss: 0.2135 - val_mae: 4.2560
# Epoch 242/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 3.5016e-06 - mae: 0.0074 - val_loss: 0.2135 - val_mae: 4.2560
# Epoch 243/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 3.3582e-06 - mae: 0.0073 - val_loss: 0.2135 - val_mae: 4.2562
# Epoch 244/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 3.2207e-06 - mae: 0.0070 - val_loss: 0.2135 - val_mae: 4.2562
# Epoch 245/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 3.0924e-06 - mae: 0.0069 - val_loss: 0.2135 - val_mae: 4.2561
# Epoch 246/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 2.9616e-06 - mae: 0.0067 - val_loss: 0.2135 - val_mae: 4.2560
# Epoch 247/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 2.8374e-06 - mae: 0.0065 - val_loss: 0.2135 - val_mae: 4.2560
# Epoch 248/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 2.7284e-06 - mae: 0.0064 - val_loss: 0.2135 - val_mae: 4.2561
# Epoch 249/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 2.6214e-06 - mae: 0.0062 - val_loss: 0.2135 - val_mae: 4.2562
# Epoch 250/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 2.5225e-06 - mae: 0.0061 - val_loss: 0.2135 - val_mae: 4.2561
# Epoch 251/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - loss: 2.4230e-06 - mae: 0.0060 - val_loss: 0.2135 - val_mae: 4.2559
# Epoch 252/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 2.3250e-06 - mae: 0.0058 - val_loss: 0.2135 - val_mae: 4.2559
# Epoch 253/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 2.2494e-06 - mae: 0.0059 - val_loss: 0.2135 - val_mae: 4.2560
# Epoch 254/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 2.1695e-06 - mae: 0.0056 - val_loss: 0.2135 - val_mae: 4.2562
# Epoch 255/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 2.0961e-06 - mae: 0.0056 - val_loss: 0.2135 - val_mae: 4.2561
# Epoch 256/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 2.0273e-06 - mae: 0.0057 - val_loss: 0.2135 - val_mae: 4.2559
# Epoch 257/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 1.9412e-06 - mae: 0.0053 - val_loss: 0.2135 - val_mae: 4.2557
# Epoch 258/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 1.8902e-06 - mae: 0.0056 - val_loss: 0.2135 - val_mae: 4.2558
# Epoch 259/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 1.8358e-06 - mae: 0.0056 - val_loss: 0.2135 - val_mae: 4.2562
# Epoch 260/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 1.7703e-06 - mae: 0.0053 - val_loss: 0.2135 - val_mae: 4.2563
# Epoch 261/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 1.7534e-06 - mae: 0.0061 - val_loss: 0.2135 - val_mae: 4.2559
# Epoch 262/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 1.6717e-06 - mae: 0.0056 - val_loss: 0.2135 - val_mae: 4.2555
# Epoch 263/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 1.6291e-06 - mae: 0.0059 - val_loss: 0.2136 - val_mae: 4.2555
# Epoch 264/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 1.6808e-06 - mae: 0.0072 - val_loss: 0.2135 - val_mae: 4.2560
# Epoch 265/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 1.5735e-06 - mae: 0.0059 - val_loss: 0.2135 - val_mae: 4.2566
# Epoch 266/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 1.6597e-06 - mae: 0.0076 - val_loss: 0.2135 - val_mae: 4.2563
# Epoch 267/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 1.7620e-06 - mae: 0.0089 - val_loss: 0.2135 - val_mae: 4.2554
# Epoch 268/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 1.5359e-06 - mae: 0.0070 - val_loss: 0.2136 - val_mae: 4.2547
# Epoch 269/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 2.0245e-06 - mae: 0.0114 - val_loss: 0.2136 - val_mae: 4.2552
# Epoch 270/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 2.2175e-06 - mae: 0.0123 - val_loss: 0.2135 - val_mae: 4.2567
# Epoch 271/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 1.9249e-06 - mae: 0.0105 - val_loss: 0.2135 - val_mae: 4.2577
# Epoch 272/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 3.6926e-06 - mae: 0.0182 - val_loss: 0.2134 - val_mae: 4.2565
# Epoch 273/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - loss: 3.6737e-06 - mae: 0.0178 - val_loss: 0.2135 - val_mae: 4.2537
# Epoch 274/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 3.5901e-06 - mae: 0.0177 - val_loss: 0.2137 - val_mae: 4.2523
# Epoch 275/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 9.7778e-06 - mae: 0.0320 - val_loss: 0.2137 - val_mae: 4.2547
# Epoch 276/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 8.6316e-06 - mae: 0.0284 - val_loss: 0.2135 - val_mae: 4.2597
# Epoch 277/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 1.1023e-05 - mae: 0.0324 - val_loss: 0.2133 - val_mae: 4.2619
# Epoch 278/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 3.2740e-05 - mae: 0.0585 - val_loss: 0.2133 - val_mae: 4.2567
# Epoch 279/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 2.6248e-05 - mae: 0.0487 - val_loss: 0.2137 - val_mae: 4.2472
# Epoch 280/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 4.1817e-05 - mae: 0.0630 - val_loss: 0.2143 - val_mae: 4.2431
# Epoch 281/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 1.2629e-04 - mae: 0.1139 - val_loss: 0.2140 - val_mae: 4.2532
# Epoch 282/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 9.6500e-05 - mae: 0.0914 - val_loss: 0.2134 - val_mae: 4.2726
# Epoch 283/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 1.7459e-04 - mae: 0.1284 - val_loss: 0.2132 - val_mae: 4.2841
# Epoch 284/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 5.2412e-04 - mae: 0.2315 - val_loss: 0.2128 - val_mae: 4.2593
# Epoch 285/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 4.0410e-04 - mae: 0.1867 - val_loss: 0.2152 - val_mae: 4.2236
# Epoch 286/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 7.5587e-04 - mae: 0.2639 - val_loss: 0.2196 - val_mae: 4.2176
# Epoch 287/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0023 - mae: 0.4815 - val_loss: 0.2157 - val_mae: 4.2381
# Epoch 288/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0017 - mae: 0.3908 - val_loss: 0.2160 - val_mae: 4.3510
# Epoch 289/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0030 - mae: 0.5341 - val_loss: 0.2259 - val_mae: 4.5146
# Epoch 290/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0096 - mae: 1.0060 - val_loss: 0.2132 - val_mae: 4.3008
# Epoch 291/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0083 - mae: 0.8520 - val_loss: 0.2305 - val_mae: 4.1761
# Epoch 292/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0132 - mae: 1.0936 - val_loss: 0.2756 - val_mae: 4.3403
# Epoch 293/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0357 - mae: 1.8078 - val_loss: 0.2124 - val_mae: 4.1566
# Epoch 294/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0214 - mae: 1.2567 - val_loss: 0.2771 - val_mae: 5.0869
# Epoch 295/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0432 - mae: 2.0346 - val_loss: 0.2188 - val_mae: 4.4117
# Epoch 296/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0339 - mae: 1.7236 - val_loss: 0.2416 - val_mae: 4.1473
# Epoch 297/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0238 - mae: 1.4965 - val_loss: 0.2059 - val_mae: 4.1200
# Epoch 298/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0095 - mae: 0.8225 - val_loss: 0.2287 - val_mae: 4.5298
# Epoch 299/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0105 - mae: 1.0557 - val_loss: 0.2117 - val_mae: 4.1138
# Epoch 300/300
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0055 - mae: 0.6939 - val_loss: 0.2081 - val_mae: 4.1170

# %% [markdown]
# Results

# %%
res=reg.predict([Xn_roi, Cv_roi_mat])
# Out:
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step

# %% [markdown]
# Results visualization

# %%
full_vec_roi=np.zeros(nu_dim**2)+1
for i in np.arange(len(roi_index)):
    full_vec_roi[roi_index[i]]=res[i]


for i in y.index[np.array(train_input_index)[train_index]]:
    if i in cell_index and i in np.array(train_input_index)[train_index] :
        full_vec_roi[i]=y.iloc[i]

full_img_roi=np.reshape(full_vec_roi,(nu_dim,nu_dim))
full_vec_roi=pd.DataFrame(full_vec_roi)
full_roi=copy(full_vec_roi)
full_cell=pd.DataFrame(full_roi.iloc[roi_index])

#Metrics calculations
res_cell=np.array(full_vec_roi.iloc[cell_index])
full_vec_cell=np.zeros(nu_dim**2)+1
for i in np.arange(len(cell_index)):
    full_vec_cell[cell_index[i]]=res_cell[i]
full_img_cell=np.reshape(full_vec_cell,(nu_dim,nu_dim))

error_map=np.subtract(full_img_cell,y_mat)
error_map_r=(abs(np.subtract(y_mat, full_img_cell))/y_mat)*100

from skimage.metrics import structural_similarity as ssim

ssim = np.round(ssim(y_mat, full_img_cell, data_range=full_img_cell.max() - full_img_cell.min()), decimals=4)
print(ssim)

rsqr_cell=np.round(r2_score(y_cell, res_cell), decimals=4)
mae_cell=mean_absolute_error(y_cell, res_cell)


fig1=plt.figure(figsize=(14,6))

ax=fig1.add_subplot(1,2,1)
pcm=ax.imshow(y_mat, vmin=1, vmax=8)
ax.axis("off")
plt.colorbar(pcm, shrink=0.8, label="$ε_{p}$")
ax.set_title("Mapa de $ε_p$ original")


ax=fig1.add_subplot(1,2,2)
pcm=ax.imshow(full_img_roi, vmin=1, vmax=25)
ax.axis("off")
plt.colorbar(pcm, shrink=0.8, label="$ε_{p}$")
ax.set_title("Mapa de $ε_p$ predicho")
ax.text(5, 90, "$R^2 = $"+str(rsqr_cell)+"\n\nError medio\nabsoluto = \n"+str(np.round(mae_cell, decimals=4)), fontsize=11, color="#fff")#"\n\nSSIM = "+str(ssim)+

fig1.suptitle("Resultado de red neuronal (train data="+str(pctg)+"%)")

fig2=plt.figure(figsize=(14,6))

ax=fig2.add_subplot(1,2,1)
pcm=ax.imshow(error_map, cmap="RdBu", vmin=-3, vmax=3)
ax.set_title("Mapa de error absoluto")
ax.axis("off")
plt.colorbar(pcm, shrink=0.8, label="$ε_p$")
ax.text(5, 90, "$R^2 = $"+str(rsqr_cell)+"\n\nError medio\nabsoluto = \n"+str(np.round(mae_cell, decimals=4)), fontsize=11, color="#000")

ax=fig2.add_subplot(1,2,2)
pcm=ax.imshow(error_map_r, cmap="magma", vmin=0, vmax=50)
ax.set_title("Mapa de error relativo")
ax.axis("off")
plt.colorbar(pcm, shrink=0.8, label="%")


fig2.suptitle("Resultado de red neuronal (train data="+str(pctg)+"%)")

fig3=plt.figure(figsize=(14,6))

ax=fig3.add_subplot(1,2,1)
binss=np.linspace(1.25,20,32)
xaxis=range(int(np.max(binss)))
ax.hist(y_cell, histtype="step", color="#000",bins=binss)
ax.hist(full_cell, histtype="bar", color="#92def7",bins=binss)
ax.set_xticks(xaxis)
ax.set_xlim([1,np.max(binss)])
ax.set_ylim([0,1000])
ax.set_title("Distribución de datos")
ax.legend(["Original","Predicción \n(train data="+str(pctg)+"%)"])
ax.set_xlabel("$ε_{p}$")
ax.set_ylabel("Count")
ax.text(1.2, 750, "$R^2 = $"+str(rsqr_cell)+"\nError medio absoluto = "+str(np.round(mae_cell, decimals=4)), fontsize=11, color="#000")



thresh=1
print("The error map presents "+str(len(error_map[abs(error_map)>thresh]))+" error values > "+str(thresh)+" ("+str(np.round((len(error_map[abs(error_map)>thresh])/len(y_cell))*100, decimals=2))+"%)")
plt.figure()
err=pd.DataFrame(np.subtract(res_cell,y_cell))
ax=fig3.add_subplot(1,2,2)
ax = sns.kdeplot(data=err, ax=ax)
legend=ax.legend()
legend.remove()
ax.set_title("Distribución de error en datos predichos")
ax.set_xlabel("Error")
ax.set_ylabel("Densidad de probabilidad")
ax.set_xlim((-3,3))
ax.set_ylim((0,3))
ax.grid('on', alpha=0.5)
err_mean, err_std=norm.fit(err)
ax.text(-2.8, 1.25, "Centro = "+str(np.round(err_mean, decimals=4))+"\nDesv. Estándar  = "+str(np.round(err_std, decimals=4)), fontsize=11, color="#000")

fig3.suptitle("Resultado de red neuronal (train data="+str(pctg)+"%)")
# Out:
# C:\Users\mcano\AppData\Local\Temp\ipykernel_18972\1787000056.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   full_vec_roi[roi_index[i]]=res[i]
# C:\Users\mcano\AppData\Local\Temp\ipykernel_18972\1787000056.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   full_vec_roi[i]=y.iloc[i]
# C:\Users\mcano\AppData\Local\Temp\ipykernel_18972\1787000056.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   full_vec_cell[cell_index[i]]=res_cell[i]
# C:\Users\mcano\AppData\Local\Temp\ipykernel_18972\1787000056.py:23: RuntimeWarning: divide by zero encountered in divide
#   error_map_r=(abs(np.subtract(y_mat, full_img_cell))/y_mat)*100
# 0.4292
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# The error map presents 1649 error values > 1 (593.17%)
# Text(0.5, 0.98, 'Resultado de red neuronal (train data=50%)')

# %%
export=0

filename=rf'{name}_linear'
folder=rf'd:\Exports\pres240510'



if export:
    img_export(filename, folder, full_img_roi, full_cell, topography_file, nu_dim)
    histogram_export(full_cell, filename, folder)


export_ref=0

filename=rf'{name}_sim'
folder=rf'd:\Exports\pres240510'

if export_ref: 
    img_export(filename, folder, y_mat, y_cell, topography_file, nu_dim)
    histogram_export(y_cell, filename, folder)

# %%
mapp=list(np.zeros((nu_dim**2)))
train_index_for_full_cell=np.array(cell_index)[train_index]
mapp=[y.iloc[i,0] if i in train_index_for_full_cell else 0 for i in range(len(mapp))]
mapp=np.array(mapp).reshape(nu_dim,nu_dim)

fig=plt.figure(figsize=(24,4))
ax=fig.add_subplot(1,4,1)
ax.imshow(np.rot90(T_mat), cmap='afmhot')
ax.set_title('Topography')
ax.axis('off')

ax=fig.add_subplot(1,4,2)
pcm=ax.imshow(np.rot90(mapp), cmap=newcmp, vmin=0, vmax=20)
ax.set_title(f'Training data points ({pctg}% of ROI)')
ax.axis('off')
plt.colorbar(pcm, label=f'$ε_p$')

ax=fig.add_subplot(1,4,3)
pcm=ax.imshow(np.rot90(full_img_roi), vmin=1, vmax=20)
ax.set_title('Neural network prediction')
ax.axis('off')
plt.colorbar(pcm, label=f'$ε_p$')

ax=fig.add_subplot(1,4,4)

ax.hist(y_cell, histtype="step", color="#000",bins=binss)
ax.hist(res_cell, histtype="bar", color="#92def7",bins=binss)
ax.set_xticks(xaxis)
ax.set_xlim([1,np.max(binss)])
ax.set_ylim([0,40])
ax.set_title("Histogram comparison")
ax.legend(["Original","Prediction \n(train data="+str(pctg)+"%)"])
ax.set_xlabel("$ε_{p}$")
ax.set_ylabel("Count")
ax.grid('on', linestyle=':', alpha=0.7)
ax.minorticks_on()
