# %% [markdown]
# ## Neural network playing ground (Small Methods Imgs)
# ### Nov 2023 - Code by Mauricio Cano Galván

# %% [markdown]
# Library Import

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from copy import copy


from sklearn.metrics import r2_score, mean_absolute_error
from matplotlib import colormaps
from matplotlib.colors import ListedColormap
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import ShuffleSplit
from scipy.stats import norm
import seaborn as sns
import math
from tqdm import tqdm

from nn_backend.import_xyz_img import import_xyz_img
from nn_backend.conv_imgs import conv_imgs
from nn_backend.data_import import import_curves_from_folder, curve_calibration, matrix_cut, data_augment, mask_from_topo
from nn_backend.nn_for_ep import nn_for_ep
from nn_backend.post_process import img_export, histogram_export
from nn_backend.extras import simulation_table_import


viridis = colormaps['viridis']
newcolors = viridis(np.linspace(0, 1, 256))
black = np.array([0, 0, 0, 1])
newcolors[0:13, :] = black
newcmp = ListedColormap(newcolors)
del black, newcolors, viridis

# %%
#Program configuration

#Data import
name='efm9' #Filename with which to save exports
topography_file=rf'c:\Users\mcano\Code\rawdata\img_data\Bacterias_Ruben\Out_Get_10_EpOnpx_2024-5-16-12-17\FlattenTopo_.txt'
ref_file=rf"c:\Users\mcano\Code\rawdata\img_data\Bacterias_Ruben\Out_Get_10_EpOnpx_2024-5-16-12-17\Map_Ep.txt"
sim_tables_folder=rf'C:\Users\mcano\Code\rawdata\img_data\Bacterias_Ruben\Out_Get_10_EpOnpx_2024-5-16-12-17\tablas'
lift_imgs_folder=rf'C:\Users\mcano\Code\rawdata\img_data\Bacterias_Ruben\Out_Get_10_EpOnpx_2024-5-16-12-17\lifts'
raw_curves_folder=0
calibrate_curves=1
ref_flip=0
topo_flip=1


#Curve pre-processing
curves_max_limit=1000 #Maximum height [nm] to which the approximation curves will be projected
curve_nsamples=12 #Number of samples to take from approximation curves
curve_height_setpoint=20 #First curve height [nm] to take in consideration for sampling


#Optional graphics to show in notebook (1 to show images, 0 to hide)
input_imgs_view=1


#Neural Network Setup
pctg=90 #Percentage of train data
cutout_size=33 #Size of the topography cutouts for the convolution operation
kernel_dim=3 #Kernel dimension for the convolution operation
iterations=300
batch_sz=200 #Batch size for training

#Mask configuration. The following images should be processed using the values established.

    #EFM9: binary_threshold=0.04, object_size=3, hole_size=30, m_thresh=0.30
    #EFM8: binary_threshold=0.41, object_size=3, hole_size=30, m_thresh=0.77
    #EFM7: binary_threshold=0.095, object_size=4, hole_size=15, m_thresh=0.44
    #EFVM: binary_threshold=0.05, object_size=2, hole_size=2, m_thresh=0.785
    #newbact: binary_threshold=0.067, object_size=3, hole_size=30, m_thresh=0.30
binary_threshold=0.067
object_size=3
hole_size=30
m_ep_thresh=0.30

# %% [markdown]
# Data Import

# %%
dimtest, x, y2 = import_xyz_img(topography_file)
og_dim=len(dimtest)

# %%
use_lift_files=1
if use_lift_files:
    lifts=[20,30,40,80,150]
    samples=lifts
    lift_samples=np.zeros((og_dim,og_dim,1))
    for l in lifts:
        file, ax_ep, ay_ep= import_xyz_img(rf'{lift_imgs_folder}\LiftPower_{l}_.txt')
        file=np.expand_dims(file,axis=-1)
        lift_samples=np.concatenate((lift_samples,file), axis=-1)
        
    lift_samples=lift_samples[:,:,1:]

# %%
#------Import the label data (εp map), as a matrix first and then transformed into a DataFrame.------#
#----------The data is then cleaned to remove outliers

nu_dim=og_dim-cutout_size+1

y_mat, ax_ep, ay_ep= import_xyz_img(ref_file)
if ref_flip:
    y_mat=np.flipud(y_mat)
y_mat=matrix_cut(y_mat,nu_dim)
y=pd.DataFrame(np.reshape(y_mat,nu_dim**2))


#Logarithmic sampling
zetas=np.arange(curves_max_limit)
maxlen=1713


zs=np.round((np.logspace(start=0,stop=math.log10(maxlen),num=curve_nsamples,endpoint=False)+curve_height_setpoint)).astype(int)
samples = []
[samples.append(x) for x in zs if x not in samples]


if use_lift_files:
    curves_sampled=matrix_cut(lift_samples, nu_dim)
    curves_sampled=curves_sampled.reshape(nu_dim*nu_dim,len(lifts))
    #curves_sampled=curves_sampled[:3]
    b=np.zeros((curves_max_limit,1))

    zzz=np.array(lifts)
    projection = np.full((len(curves_sampled),len(zetas)), np.nan)
    for h in tqdm(np.arange(len(curves_sampled))):
        ccc=curves_sampled[h,:]
        indices = np.where(np.isin(zetas, zzz.astype(int)))[0]
        projection[h, indices] = ccc[np.isin(np.round(zzz), zetas)]
    projection=pd.DataFrame(projection)
    projection=projection.interpolate(axis=1)
    projection=projection.bfill(axis=1)
    curves_sampled=np.array(projection).reshape(nu_dim,nu_dim,curves_max_limit)
    curves_sampled=curves_sampled[:,:,samples]
    
else:


    #New curves
    curves=(np.array(curves_projected)).reshape(og_dim,og_dim,len(curves_projected.iloc[0,:]))
    curves=matrix_cut(curves, nu_dim)
    curves_sampled=curves[:,:,samples]

#Topography import
T_mat, x, y2 = import_xyz_img(topography_file)
T_mat=matrix_cut(T_mat, nu_dim)
T_mat=np.expand_dims(T_mat, axis=2)
T=T_mat.reshape(nu_dim**2)
#Put together training dataset
X_mat=np.concatenate((T_mat, curves_sampled), axis=2)

aa=["Z = "+str(x)+" nm" for x in samples]
inputs=["Topography"]
inputs=np.append(inputs, aa)

X=np.reshape(X_mat,(nu_dim**2,len(X_mat[0,0,:])))
X=pd.DataFrame(X, columns=inputs)


plt.subplot(1,2,1)
plt.imshow(T_mat, cmap='hot')
plt.title('Topography')
plt.axis('off')
plt.subplot(1,2,2)
plt.imshow(y_mat, cmap=newcmp, vmin=-1, vmax=8)
plt.title('$ε_p$ map')
plt.axis('off')
# Out:
# 100%|██████████| 50176/50176 [00:08<00:00, 5646.73it/s]
# (-0.5, 223.5, 223.5, -0.5)

# %%
if input_imgs_view:
    fig=plt.figure(figsize=(12,10))
    ax=fig.add_subplot(5,3,1)
    pcm=ax.imshow(X_mat[:,:,0], cmap='hot')
    ax.set_title("Topography")
    plt.colorbar(pcm, label="nm")
    ax.axis('off')
    for i in range(2,len(X.iloc[0])+1):
        ax=fig.add_subplot(5,3,i)
        pcm=ax.imshow(X_mat[:,:,i-1], cmap='hot', vmin=0.0, vmax=0.015)
        h=samples[i-2]
        ax.set_title("Lift; Z = "+str(h)+" nm")
        plt.colorbar(pcm, label="$dC/dz$")
        ax.axis('off')

# %% [markdown]
# Data Pre-Processing

# %%
# binary_threshold=0.9905
# object_size=3
# hole_size=30
# m_ep_thresh=0.30

masker=T

bin=mask_from_topo(masker,binary_threshold,object_size,hole_size)

cell=bin.reshape(nu_dim**2,1)
roi_index=pd.DataFrame(copy(cell))
roi_index=roi_index.index[(roi_index[0])]


mask_ep=pd.DataFrame(copy(y))
th=float(mask_ep.quantile(m_ep_thresh))

mask_ep[(mask_ep[0]<=th)]=0
mask_ep[(mask_ep[0]!=0)]=1
mask_ep=cell*mask_ep
mask_ep_im=np.reshape(np.array(mask_ep), ((nu_dim),(nu_dim)))

cell_index=mask_ep.index[mask_ep[0]>0].tolist()


fig=plt.figure(figsize=(10,7))
ax=fig.add_subplot(1,2,1)
ax.imshow(bin, cmap='gray')
ax.set_title('ROI mask')
ax.axis('off')
ax=fig.add_subplot(1,2,2)
ax.imshow(mask_ep_im)
ax.axis('off')
ax.set_title('Final Train Mask')
# Out:
# C:\Users\mcano\AppData\Local\Temp\ipykernel_16740\3513037825.py:16: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   th=float(mask_ep.quantile(m_ep_thresh))
# Text(0.5, 1.0, 'Final Train Mask')

# %%
plt.hist(masker)
plt.imshow(np.array(masker).reshape(224,224))

# %%
#------Cell separation------#
y_cell=pd.DataFrame(y.iloc[cell_index])
X_cell=pd.DataFrame(X.iloc[cell_index])
y_roi=pd.DataFrame(y.iloc[roi_index])
X_roi=pd.DataFrame(X.iloc[roi_index])


#------Data Normalization------#
curve_scale=StandardScaler()
curve_scale.fit(X_cell)
Xn_cell=pd.DataFrame(curve_scale.transform(X_cell), columns=inputs)
Xn_roi=pd.DataFrame(curve_scale.transform(X_roi), columns=inputs)

# %%
#------Data Normalization------#
curve_scale=StandardScaler()
curve_scale.fit(X_cell)
Xn_cell=pd.DataFrame(curve_scale.transform(X_cell), columns=inputs)

# %%
topo_mat, x, y2 = import_xyz_img(topography_file)
topo=topo_mat.reshape(len(topo_mat)**2,1)

topo_scale=StandardScaler()
topo_scale.fit(topo)
topo_n=topo_scale.transform(topo)
topo_n_mat=topo_n.reshape(len(topo_mat),len(topo_mat),1)

# %%
full_cutouts=0

if full_cutouts:
    Cv_mat=conv_imgs(topo_n_mat[:,:,0], cutout_size)
    Cv_mat=Cv_mat.reshape(int(math.sqrt(len(Cv_mat))),int(math.sqrt(len(Cv_mat))),cutout_size,cutout_size)
    Cv_mat=matrix_cut(Cv_mat, nu_dim)

    Cv_mat=Cv_mat.reshape(nu_dim*nu_dim,cutout_size,cutout_size)
    Cv_mat=np.expand_dims(Cv_mat, axis=-1)

    Cv_mat=Cv_mat.reshape(nu_dim*nu_dim,cutout_size,cutout_size)
    Cv_mat=np.expand_dims(Cv_mat, axis=-1)
    Cv_cell_mat=Cv_mat[cell_index,:,:,:]
    Cv_roi_mat=Cv_mat[roi_index,:,:,:]
    # Cv_tab_mat=Cv_mat[tab_index,:,:,:]
else:
    y_coord, x_coord= np.unravel_index(cell_index, (nu_dim, nu_dim))
    cell_index_2=np.transpose(np.column_stack((y_coord, x_coord)))
    cell_index_2[0]=cell_index_2[0]+int((cutout_size-1)/2)
    cell_index_2[1]=cell_index_2[1]+int((cutout_size-1)/2)

    y_coord, x_coord= np.unravel_index(roi_index, (nu_dim, nu_dim))
    roi_index_2=np.transpose(np.column_stack((y_coord, x_coord)))
    roi_index_2[0]=roi_index_2[0]+int((cutout_size-1)/2)
    roi_index_2[1]=roi_index_2[1]+int((cutout_size-1)/2)


    Cv_cell_mat=conv_imgs(topo_n_mat[:,:,0], cutout_size, cell_index_2)
    Cv_no_norm_mat=conv_imgs(topo_mat[:,:], cutout_size, cell_index_2)
    Cv_roi_mat=conv_imgs(topo_n_mat[:,:,0], cutout_size, roi_index_2)
    Cv_cell_mat=np.expand_dims(Cv_cell_mat, axis=-1)
    Cv_roi_mat=np.expand_dims(Cv_roi_mat, axis=-1)
# Out:
# 100%|██████████| 503/503 [00:00<00:00, 1064.04it/s]
# 100%|██████████| 503/503 [00:00<00:00, 1108.53it/s]
# 100%|██████████| 5675/5675 [00:46<00:00, 122.91it/s]

# %%
ii=300
print(Cv_no_norm_mat[ii,16,16])
print(X_cell.iloc[ii,0])
# Out:
# 1.0404e-07
# 1.0404e-07

# %%
Xn_train_input=Xn_cell
y_train_input=y_cell
Cv_train_input=Cv_cell_mat
train_input_index=cell_index

# Xn_train_input=Xn_tab
# y_train_input=y_tab
# Cv_train_input=Cv_tab_mat
# train_input_index=tab_index

# %% [markdown]
# Test-Train Separation

# %%
pctg=50
sss = ShuffleSplit(n_splits=1, test_size=1-(pctg/100), random_state=1)
sss.get_n_splits(Xn_train_input, y_train_input)
train_index, test_index = next(sss.split(Xn_train_input, y_train_input))
train_index=np.sort(train_index)  
test_index=np.sort(test_index)  



X_train, X_test = Xn_train_input.iloc[train_index], Xn_train_input.iloc[test_index] 
y_train, y_test = y_train_input.iloc[train_index], y_train_input.iloc[test_index]

Cv_train, Cv_test = Cv_train_input[train_index,:,:], Cv_train_input[test_index,:,:] 
Cv_train_aug=data_augment(Cv_train)


N_aug=int(len(Cv_train_aug[:,0,0,0])/len(Cv_train[:,0,0,0]))

X_train_aug=copy(X_train)
y_train_aug=copy(y_train)
for i in np.arange(N_aug-1):
    X_train_aug=pd.DataFrame(np.concatenate((X_train_aug, X_train), axis=0))
    y_train_aug=pd.DataFrame(np.concatenate((y_train_aug, y_train), axis=0))

# %% [markdown]
# Network Architecture

# %%
#------Example Keras Network------#
reg, histo=nn_for_ep(X_train_aug,Cv_train_aug,y_train_aug,X_test,Cv_test,y_test, verb=1)
# Out:
# Epoch 1/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - loss: 2.5616 - mae: 8.6409 - val_loss: 0.3647 - val_mae: 4.7645
# Epoch 2/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.3103 - mae: 4.8121 - val_loss: 0.2413 - val_mae: 4.3713
# Epoch 3/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - loss: 0.2420 - mae: 4.5071 - val_loss: 0.2207 - val_mae: 4.1988
# Epoch 4/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.2310 - mae: 4.3599 - val_loss: 0.2155 - val_mae: 4.1631
# Epoch 5/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - loss: 0.2260 - mae: 4.3077 - val_loss: 0.2143 - val_mae: 4.1430
# Epoch 6/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.2237 - mae: 4.3067 - val_loss: 0.2141 - val_mae: 4.1424
# Epoch 7/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0
300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 0.0169 - mae: 1.2231 - val_loss: 0.1498 - val_mae: 3.2765
# Epoch 75/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 0.0154 - mae: 1.1684 - val_loss: 0.1623 - val_mae: 3.3973
# Epoch 76/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.0170 - mae: 1.2362 - val_loss: 0.1451 - val_mae: 3.2441
# Epoch 77/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.0122 - mae: 1.0559 - val_loss: 0.1458 - val_mae: 3.2152
# Epoch 78/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0111 - mae: 1.0152 - val_loss: 0.1506 - val_mae: 3.2526
# Epoch 79/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 0.0112 - mae: 1.0281 - val_loss: 0.1526 - val_mae: 3.3449
# Epoch 80/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.0105 - mae: 0.9909 - val_loss: 0.1520 - val_mae: 3.3542
# Epoch 81/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0110 - mae: 0.9772 - val_loss: 0.1570 - val_mae: 3.3710
# Epoch 82/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - loss: 0.0131 - mae: 1.0407 - val_loss: 0.1500 - val_mae: 3.3027
# Epoch 83/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - loss: 0.0105 - mae: 0.9437 - val_loss: 0.1594 - val_mae: 3.3789
# Epoch 84/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 0.0123 - mae: 1.0308 - val_loss: 0.1490 - val_mae: 3.2815
# Epoch 85/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0099 - mae: 0.9379 - val_loss: 0.1444 - val_mae: 3.2129
# Epoch 86/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.0086 - mae: 0.8764 - val_loss: 0.1474 - val_mae: 3.2143
# Epoch 87/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0066 - mae: 0.7881 - val_loss: 0.1538 - val_mae: 3.3497
# Epoch 88/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0063 - mae: 0.7696 - val_loss: 0.1558 - val_mae: 3.4026
# Epoch 89/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.0064 - mae: 0.7537 - val_loss: 0.1519 - val_mae: 3.3367
# Epoch 90/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.0067 - mae: 0.7613 - val_loss: 0.1487 - val_mae: 3.2697
# Epoch 91/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0056 - mae: 0.7068 - val_loss: 0.1485 - val_mae: 3.2460
# Epoch 92/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0052 - mae: 0.6885 - val_loss: 0.1548 - val_mae: 3.3003
# Epoch 93/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.0059 - mae: 0.7161 - val_loss: 0.1510 - val_mae: 3.2674
# Epoch 94/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0064 - mae: 0.7578 - val_loss: 0.1433 - val_mae: 3.2086
# Epoch 95/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 0.0068 - mae: 0.7779 - val_loss: 0.1486 - val_mae: 3.2788
# Epoch 96/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - loss: 0.0085 - mae: 0.8543 - val_loss: 0.1514 - val_mae: 3.3376
# Epoch 97/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.0075 - mae: 0.8140 - val_loss: 0.1693 - val_mae: 3.5342
# Epoch 98/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.0087 - mae: 0.8442 - val_loss: 0.1541 - val_mae: 3.3390
# Epoch 99/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0071 - mae: 0.7815 - val_loss: 0.1424 - val_mae: 3.1938
# Epoch 100/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - loss: 0.0055 - mae: 0.7051 - val_loss: 0.1484 - val_mae: 3.2420
# Epoch 101/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0045 - mae: 0.6396 - val_loss: 0.1548 - val_mae: 3.2984
# Epoch 102/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.0052 - mae: 0.6819 - val_loss: 0.1442 - val_mae: 3.1907
# Epoch 103/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.0046 - mae: 0.6323 - val_loss: 0.1462 - val_mae: 3.2446
# Epoch 104/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0048 - mae: 0.6574 - val_loss: 0.1567 - val_mae: 3.4026
# Epoch 105/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.0045 - mae: 0.6369 - val_loss: 0.1627 - val_mae: 3.4689
# Epoch 106/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0053 - mae: 0.6895 - val_loss: 0.1509 - val_mae: 3.3127
# Epoch 107/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.
300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 0.0259 - mae: 1.4330 - val_loss: 0.1387 - val_mae: 3.1230
# Epoch 142/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0175 - mae: 1.1914 - val_loss: 0.1466 - val_mae: 3.1916
# Epoch 143/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.0113 - mae: 0.9692 - val_loss: 0.1435 - val_mae: 3.1602
# Epoch 144/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.0085 - mae: 0.8339 - val_loss: 0.1446 - val_mae: 3.2207
# Epoch 145/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0114 - mae: 0.9709 - val_loss: 0.1426 - val_mae: 3.2016
# Epoch 146/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0132 - mae: 1.0312 - val_loss: 0.1404 - val_mae: 3.1224
# Epoch 147/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0100 - mae: 0.8987 - val_loss: 0.1446 - val_mae: 3.1541
# Epoch 148/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - loss: 0.0076 - mae: 0.8058 - val_loss: 0.1434 - val_mae: 3.1351
# Epoch 149/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0053 - mae: 0.6687 - val_loss: 0.1418 - val_mae: 3.1399
# Epoch 150/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0050 - mae: 0.6436 - val_loss: 0.1438 - val_mae: 3.1831
# Epoch 151/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.0064 - mae: 0.7356 - val_loss: 0.1433 - val_mae: 3.1656
# Epoch 152/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.0069 - mae: 0.7503 - val_loss: 0.1413 - val_mae: 3.1190
# Epoch 153/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.0057 - mae: 0.6718 - val_loss: 0.1437 - val_mae: 3.1362
# Epoch 154/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.0047 - mae: 0.6420 - val_loss: 0.1437 - val_mae: 3.1304
# Epoch 155/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - loss: 0.0038 - mae: 0.5754 - val_loss: 0.1417 - val_mae: 3.1163
# Epoch 156/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 0.0028 - mae: 0.4906 - val_loss: 0.1421 - val_mae: 3.1315
# Epoch 157/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 0.0028 - mae: 0.4954 - val_loss: 0.1434 - val_mae: 3.1549
# Epoch 158/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.0036 - mae: 0.5596 - val_loss: 0.1438 - val_mae: 3.1578
# Epoch 159/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0042 - mae: 0.5967 - val_loss: 0.1425 - val_mae: 3.1288
# Epoch 160/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0039 - mae: 0.5654 - val_loss: 0.1421 - val_mae: 3.1124
# Epoch 161/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - loss: 0.0036 - mae: 0.5535 - val_loss: 0.1442 - val_mae: 3.1334
# Epoch 162/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.0036 - mae: 0.5807 - val_loss: 0.1442 - val_mae: 3.1377
# Epoch 163/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0034 - mae: 0.5624 - val_loss: 0.1423 - val_mae: 3.1169
# Epoch 164/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.0024 - mae: 0.4718 - val_loss: 0.1406 - val_mae: 3.1001
# Epoch 165/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.0019 - mae: 0.4175 - val_loss: 0.1425 - val_mae: 3.1426
# Epoch 166/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0026 - mae: 0.4926 - val_loss: 0.1470 - val_mae: 3.2232
# Epoch 167/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0042 - mae: 0.6273 - val_loss: 0.1476 - val_mae: 3.2323
# Epoch 168/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - loss: 0.0053 - mae: 0.7110 - val_loss: 0.1428 - val_mae: 3.1336
# Epoch 169/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0047 - mae: 0.6480 - val_loss: 0.1416 - val_mae: 3.1045
# Epoch 170/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - loss: 0.0043 - mae: 0.6270 - val_loss: 0.1486 - val_mae: 3.1824
# Epoch 171/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0058 - mae: 0.7294 - val_loss: 0.1500 - val_mae: 3.2035
# Epoch 172/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0064 - mae: 0.7778 - val_loss: 0.1436 - val_mae: 3.1381
# Epoch 173/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0043 - mae: 0.6446 - val_loss: 0.1398 - val_mae: 3.1032
# Epoch 174/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - loss: 0.0029 - mae: 0.5150 - val_loss: 0.1458 - val_mae: 3.2181
# Epoch 175/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - loss: 0.0044 - mae: 0.6495 - val_loss: 0.1518 - val_mae: 3.3341
# Epoch 176/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0070 - mae: 0.8328 - val_loss: 0.1467 - val_mae: 3.2346
# Epoch 177/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.0070 - mae: 0.8289 - val_loss: 0.1398 - val_mae: 3.0947
# Epoch 178/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 0.0047 - mae: 0.6417 - val_loss: 0.1485 - val_mae: 3.1852
# Epoch 179/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0059 - mae: 0.7335 - val_loss: 0.1528 - val_mae: 3.2210
# Epoch 180/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0070 - mae: 0.7925 - val_loss: 0.1427 - val_mae: 3.1169
# Epoch 181/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.0042 - mae: 0.6295 - val_loss: 0.1397 - val_mae: 3.1096
# Epoch 182/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.0028 - mae: 0.4992 - val_loss: 0.1458 - val_mae: 3.2248
# Epoch 183/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0040 - mae: 0.6292 - val_loss: 0.1476 - val_mae: 3.2582
# Epoch 184/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.0051 - mae: 0.7213 - val_loss: 0.1413 - val_mae: 3.1311
# Epoch 185/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0041 - mae: 0.6129 - val_loss: 0.1425 - val_mae: 3.1343
# Epoch 186/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0033 - mae: 0.5551 - val_loss: 0.1500 - val_mae: 3.2000
# Epoch 187/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0049 - mae: 0.6641 - val_loss: 0.1455 - val_mae: 3.1545
# Epoch 188/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.0040 - mae: 0.6277 - val_loss: 0.1396 - val_mae: 3.0904
# Epoch 189/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.0023 - mae: 0.4548 - val_loss: 0.1429 - val_mae: 3.1586
# Epoch 190/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0025 - mae: 0.4905 - val_loss: 0.1450 - val_mae: 3.2167
# Epoch 191/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - loss: 0.0037 - mae: 0.6105 - val_loss: 0.1420 - val_mae: 3.1456
# Epoch 192/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.0034 - mae: 0.5777 - val_loss: 0.1412 - val_mae: 3.1158
# Epoch 193/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0024 - mae: 0.4706 - val_loss: 0.1463 - val_mae: 3.1694
# Epoch 194/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0034 - mae: 0.5604 - val_loss: 0.1460 - val_mae: 3.1664
# Epoch 195/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0037 - mae: 0.6025 - val_loss: 0.1408 - val_mae: 3.0984
# Epoch 196/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0022 - mae: 0.4570 - val_loss: 0.1408 - val_mae: 3.1191
# Epoch 197/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0019 - mae: 0.4189 - val_loss: 0.1444 - val_mae: 3.2042
# Epoch 198/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - loss: 0.0030 - mae: 0.5437 - val_loss: 0.1438 - val_mae: 3.1808
# Epoch 199/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.0033 - mae: 0.5801 - val_loss: 0.1408 - val_mae: 3.1139
# Epoch 200/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0024 - mae: 0.4595 - val_loss: 0.1441 - val_mae: 3.1499
# Epoch 201/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0026 - mae: 0.4939 - val_loss: 0.1475 - val_mae: 3.1834
# Epoch 202/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.0037 - mae: 0.6012 - val_loss: 0.1431 - val_mae: 3.1248
# Epoch 203/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0029 - mae: 0.5285 - val_loss: 0.1397 - val_mae: 3.0893
# Epoch 204/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0018 - mae: 0.3986 - val_loss: 0.1428 - val_mae: 3.1715
# Epoch 205/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0024 - mae: 0.4787 - val_loss: 0.1448 - val_mae: 3.2113
# Epoch 206/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - loss: 0.0033 - mae: 0.5883 - val_loss: 0.1422 - val_mae: 3.1413
# Epoch 207/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.0028 - mae: 0.5261 - val_loss: 0.1417 - val_mae: 3.1232
# Epoch 208/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0021 - mae: 0.4502 - val_loss: 0.1469 - val_mae: 3.1808
# Epoch 209/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0032 - mae: 0.5579 - val_loss: 0.1467 - val_mae: 3.1704
# Epoch 210/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 0.0036 - mae: 0.6009 - val_loss: 0.1411 - val_mae: 3.0995
# Epoch 211/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0023 - mae: 0.4569 - val_loss: 0.1404 - val_mae: 3.1146
# Epoch 212/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0019 - mae: 0.4072 - val_loss: 0.1445 - val_mae: 3.2095
# Epoch 213/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 0.0029 - mae: 0.5375 - val_loss: 0.1445 - val_mae: 3.1965
# Epoch 214/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 0.0033 - mae: 0.5931 - val_loss: 0.1410 - val_mae: 3.1199
# Epoch 215/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.0024 - mae: 0.4694 - val_loss: 0.1436 - val_mae: 3.1465
# Epoch 216/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - loss: 0.0024 - mae: 0.4787 - val_loss: 0.1482 - val_mae: 3.1911
# Epoch 217/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0037 - mae: 0.6021 - val_loss: 0.1447 - val_mae: 3.1402
# Epoch 218/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.0032 - mae: 0.5571 - val_loss: 0.1400 - val_mae: 3.0871
# Epoch 219/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0020 - mae: 0.4174 - val_loss: 0.1418 - val_mae: 3.1549
# Epoch 220/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.0023 - mae: 0.4523 - val_loss: 0.1452 - val_mae: 3.2223
# Epoch 221/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.0032 - mae: 0.5755 - val_loss: 0.1430 - val_mae: 3.1616
# Epoch 222/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.0030 - mae: 0.5555 - val_loss: 0.1411 - val_mae: 3.1202
# Epoch 223/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 0.0022 - mae: 0.4475 - val_loss: 0.1462 - val_mae: 3.1747
# Epoch 224/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0029 - mae: 0.5271 - val_loss: 0.1482 - val_mae: 3.1923
# Epoch 225/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 0.0038 - mae: 0.6232 - val_loss: 0.1429 - val_mae: 3.1153
# Epoch 226/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0026 - mae: 0.4907 - val_loss: 0.1405 - val_mae: 3.0993
# Epoch 227/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0019 - mae: 0.4028 - val_loss: 0.1441 - val_mae: 3.2016
# Epoch 228/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0028 - mae: 0.5117 - val_loss: 0.1451 - val_mae: 3.2112
# Epoch 229/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 0.0033 - mae: 0.5988 - val_loss: 0.1421 - val_mae: 3.1282
# Epoch 230/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.0026 - mae: 0.4897 - val_loss: 0.1431 - val_mae: 3.1424
# Epoch 231/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0023 - mae: 0.4727 - val_loss: 0.1485 - val_mae: 3.2003
# Epoch 232/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0036 - mae: 0.5985 - val_loss: 0.1466 - val_mae: 3.1625
# Epoch 233/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 0.0035 - mae: 0.6007 - val_loss: 0.1414 - val_mae: 3.0950
# Epoch 234/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.0021 - mae: 0.4312 - val_loss: 0.1422 - val_mae: 3.1475
# Epoch 235/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0023 - mae: 0.4497 - val_loss: 0.1453 - val_mae: 3.2328
# Epoch 236/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.0033 - mae: 0.5755 - val_loss: 0.1433 - val_mae: 3.1620
# Epoch 237/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - loss: 0.0030 - mae: 0.5645 - val_loss: 0.1426 - val_mae: 3.1297
# Epoch 238/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.0022 - mae: 0.4520 - val_loss: 0.1471 - val_mae: 3.1864
# Epoch 239/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0029 - mae: 0.5288 - val_loss: 0.1483 - val_mae: 3.1965
# Epoch 240/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.0037 - mae: 0.6280 - val_loss: 0.1435 - val_mae: 3.1197
# Epoch 241/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0027 - mae: 0.5088 - val_loss: 0.1415 - val_mae: 3.1036
# Epoch 242/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0020 - mae: 0.4185 - val_loss: 0.1444 - val_mae: 3.2034
# Epoch 243/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0029 - mae: 0.5262 - val_loss: 0.1450 - val_mae: 3.2100
# Epoch 244/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - loss: 0.0033 - mae: 0.5969 - val_loss: 0.1416 - val_mae: 3.1213
# Epoch 245/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0024 - mae: 0.4754 - val_loss: 0.1451 - val_mae: 3.1584
# Epoch 246/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0024 - mae: 0.4794 - val_loss: 0.1490 - val_mae: 3.2002
# Epoch 247/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.0036 - mae: 0.5947 - val_loss: 0.1460 - val_mae: 3.1568
# Epoch 248/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.0032 - mae: 0.5821 - val_loss: 0.1416 - val_mae: 3.0958
# Epoch 249/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0019 - mae: 0.4104 - val_loss: 0.1431 - val_mae: 3.1563
# Epoch 250/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0025 - mae: 0.4685 - val_loss: 0.1450 - val_mae: 3.2213
# Epoch 251/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.0033 - mae: 0.5736 - val_loss: 0.1424 - val_mae: 3.1308
# Epoch 252/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0026 - mae: 0.5065 - val_loss: 0.1436 - val_mae: 3.1399
# Epoch 253/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - loss: 0.0022 - mae: 0.4503 - val_loss: 0.1490 - val_mae: 3.2017
# Epoch 254/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.0032 - mae: 0.5587 - val_loss: 0.1469 - val_mae: 3.1686
# Epoch 255/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - loss: 0.0033 - mae: 0.5975 - val_loss: 0.1421 - val_mae: 3.1007
# Epoch 256/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.0022 - mae: 0.4484 - val_loss: 0.1431 - val_mae: 3.1363
# Epoch 257/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 0.0022 - mae: 0.4454 - val_loss: 0.1456 - val_mae: 3.2248
# Epoch 258/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 0.0031 - mae: 0.5571 - val_loss: 0.1443 - val_mae: 3.1768
# Epoch 259/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 0.0029 - mae: 0.5517 - val_loss: 0.1428 - val_mae: 3.1282
# Epoch 260/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.0022 - mae: 0.4410 - val_loss: 0.1478 - val_mae: 3.1929
# Epoch 261/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0027 - mae: 0.5035 - val_loss: 0.1479 - val_mae: 3.1866
# Epoch 262/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.0034 - mae: 0.5960 - val_loss: 0.1446 - val_mae: 3.1248
# Epoch 263/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.0026 - mae: 0.5036 - val_loss: 0.1425 - val_mae: 3.1167
# Epoch 264/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.0017 - mae: 0.3796 - val_loss: 0.1438 - val_mae: 3.1850
# Epoch 265/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.0028 - mae: 0.5006 - val_loss: 0.1441 - val_mae: 3.1796
# Epoch 266/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - loss: 0.0031 - mae: 0.5443 - val_loss: 0.1430 - val_mae: 3.1231
# Epoch 267/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.0020 - mae: 0.4125 - val_loss: 0.1472 - val_mae: 3.1631
# Epoch 268/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0025 - mae: 0.4569 - val_loss: 0.1476 - val_mae: 3.1822
# Epoch 269/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - loss: 0.0035 - mae: 0.5863 - val_loss: 0.1417 - val_mae: 3.1163
# Epoch 270/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.0027 - mae: 0.5340 - val_loss: 0.1403 - val_mae: 3.0881
# Epoch 271/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0023 - mae: 0.4514 - val_loss: 0.1449 - val_mae: 3.1685
# Epoch 272/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - loss: 0.0027 - mae: 0.5163 - val_loss: 0.1477 - val_mae: 3.2471
# Epoch 273/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.0031 - mae: 0.5825 - val_loss: 0.1433 - val_mae: 3.1587
# Epoch 274/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0028 - mae: 0.5334 - val_loss: 0.1422 - val_mae: 3.1431
# Epoch 275/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.0021 - mae: 0.4373 - val_loss: 0.1477 - val_mae: 3.2038
# Epoch 276/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - loss: 0.0027 - mae: 0.5117 - val_loss: 0.1477 - val_mae: 3.1586
# Epoch 277/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - loss: 0.0032 - mae: 0.5529 - val_loss: 0.1449 - val_mae: 3.1059
# Epoch 278/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.0022 - mae: 0.4125 - val_loss: 0.1401 - val_mae: 3.0969
# Epoch 279/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - loss: 0.0016 - mae: 0.3122 - val_loss: 0.1423 - val_mae: 3.1561
# Epoch 280/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.0026 - mae: 0.4194 - val_loss: 0.1464 - val_mae: 3.1925
# Epoch 281/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0024 - mae: 0.5045 - val_loss: 0.1435 - val_mae: 3.1263
# Epoch 282/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 0.0018 - mae: 0.4225 - val_loss: 0.1445 - val_mae: 3.1689
# Epoch 283/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.0018 - mae: 0.4209 - val_loss: 0.1473 - val_mae: 3.1977
# Epoch 284/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0030 - mae: 0.5758 - val_loss: 0.1478 - val_mae: 3.1409
# Epoch 285/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.0029 - mae: 0.5426 - val_loss: 0.1420 - val_mae: 3.0773
# Epoch 286/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.0018 - mae: 0.3897 - val_loss: 0.1409 - val_mae: 3.1333
# Epoch 287/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.0023 - mae: 0.4201 - val_loss: 0.1441 - val_mae: 3.2050
# Epoch 288/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.0031 - mae: 0.5456 - val_loss: 0.1438 - val_mae: 3.1503
# Epoch 289/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 0.0024 - mae: 0.5017 - val_loss: 0.1438 - val_mae: 3.1363
# Epoch 290/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 0.0019 - mae: 0.4195 - val_loss: 0.1489 - val_mae: 3.2229
# Epoch 291/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - loss: 0.0030 - mae: 0.5602 - val_loss: 0.1475 - val_mae: 3.1687
# Epoch 292/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.0035 - mae: 0.6113 - val_loss: 0.1431 - val_mae: 3.0949
# Epoch 293/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - loss: 0.0023 - mae: 0.4713 - val_loss: 0.1425 - val_mae: 3.1296
# Epoch 294/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 0.0021 - mae: 0.4278 - val_loss: 0.1448 - val_mae: 3.2003
# Epoch 295/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.0034 - mae: 0.5720 - val_loss: 0.1455 - val_mae: 3.1953
# Epoch 296/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0031 - mae: 0.5662 - val_loss: 0.1433 - val_mae: 3.1175
# Epoch 297/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.0021 - mae: 0.4411 - val_loss: 0.1480 - val_mae: 3.2098
# Epoch 298/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.0030 - mae: 0.5492 - val_loss: 0.1493 - val_mae: 3.2120
# Epoch 299/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0038 - mae: 0.6416 - val_loss: 0.1443 - val_mae: 3.1017
# Epoch 300/300
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0027 - mae: 0.5238 - val_loss: 0.1432 - val_mae: 3.0957

# %% [markdown]
# Results

# %%
res=reg.predict([Xn_roi, Cv_roi_mat])
# Out:
# 178/178 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step

# %% [markdown]
# Results visualization

# %%
full_vec_roi=np.zeros(nu_dim**2)+1
for i in np.arange(len(roi_index)):
    full_vec_roi[roi_index[i]]=res[i]


for i in y.index[np.array(train_input_index)[train_index]]:
    if i in cell_index and i in np.array(train_input_index)[train_index] :
        full_vec_roi[i]=y.iloc[i]

full_img_roi=np.reshape(full_vec_roi,(nu_dim,nu_dim))
full_vec_roi=pd.DataFrame(full_vec_roi)
full_roi=copy(full_vec_roi)
full_cell=pd.DataFrame(full_roi.iloc[roi_index])

#Metrics calculations
res_cell=np.array(full_vec_roi.iloc[cell_index])
full_vec_cell=np.zeros(nu_dim**2)+1
for i in np.arange(len(cell_index)):
    full_vec_cell[cell_index[i]]=res_cell[i]
full_img_cell=np.reshape(full_vec_cell,(nu_dim,nu_dim))

error_map=np.subtract(full_img_cell,y_mat)
error_map_r=(abs(np.subtract(y_mat, full_img_cell))/y_mat)*100

from skimage.metrics import structural_similarity as ssim

ssim = np.round(ssim(y_mat, full_img_cell, data_range=full_img_cell.max() - full_img_cell.min()), decimals=4)
print(ssim)

rsqr_cell=np.round(r2_score(y_cell, res_cell), decimals=4)
mae_cell=mean_absolute_error(y_cell, res_cell)


fig1=plt.figure(figsize=(14,6))

ax=fig1.add_subplot(1,2,1)
pcm=ax.imshow(y_mat, vmin=1, vmax=8)
ax.axis("off")
plt.colorbar(pcm, shrink=0.8, label="$ε_{p}$")
ax.set_title("Mapa de $ε_p$ original")


ax=fig1.add_subplot(1,2,2)
pcm=ax.imshow(full_img_roi, vmin=1, vmax=25)
ax.axis("off")
plt.colorbar(pcm, shrink=0.8, label="$ε_{p}$")
ax.set_title("Mapa de $ε_p$ predicho")
ax.text(5, 90, "$R^2 = $"+str(rsqr_cell)+"\n\nError medio\nabsoluto = \n"+str(np.round(mae_cell, decimals=4)), fontsize=11, color="#fff")#"\n\nSSIM = "+str(ssim)+

fig1.suptitle("Resultado de red neuronal (train data="+str(pctg)+"%)")

fig2=plt.figure(figsize=(14,6))

ax=fig2.add_subplot(1,2,1)
pcm=ax.imshow(error_map, cmap="RdBu", vmin=-3, vmax=3)
ax.set_title("Mapa de error absoluto")
ax.axis("off")
plt.colorbar(pcm, shrink=0.8, label="$ε_p$")
ax.text(5, 90, "$R^2 = $"+str(rsqr_cell)+"\n\nError medio\nabsoluto = \n"+str(np.round(mae_cell, decimals=4)), fontsize=11, color="#000")

ax=fig2.add_subplot(1,2,2)
pcm=ax.imshow(error_map_r, cmap="magma", vmin=0, vmax=50)
ax.set_title("Mapa de error relativo")
ax.axis("off")
plt.colorbar(pcm, shrink=0.8, label="%")


fig2.suptitle("Resultado de red neuronal (train data="+str(pctg)+"%)")

fig3=plt.figure(figsize=(14,6))

ax=fig3.add_subplot(1,2,1)
binss=np.linspace(1.25,20,32)
xaxis=range(int(np.max(binss)))
ax.hist(y_cell, histtype="step", color="#000",bins=binss)
ax.hist(full_cell, histtype="bar", color="#92def7",bins=binss)
ax.set_xticks(xaxis)
ax.set_xlim([1,np.max(binss)])
ax.set_ylim([0,1000])
ax.set_title("Distribución de datos")
ax.legend(["Original","Predicción \n(train data="+str(pctg)+"%)"])
ax.set_xlabel("$ε_{p}$")
ax.set_ylabel("Count")
ax.text(1.2, 750, "$R^2 = $"+str(rsqr_cell)+"\nError medio absoluto = "+str(np.round(mae_cell, decimals=4)), fontsize=11, color="#000")



thresh=1
print("The error map presents "+str(len(error_map[abs(error_map)>thresh]))+" error values > "+str(thresh)+" ("+str(np.round((len(error_map[abs(error_map)>thresh])/len(y_cell))*100, decimals=2))+"%)")
plt.figure()
err=pd.DataFrame(np.subtract(res_cell,y_cell))
ax=fig3.add_subplot(1,2,2)
ax = sns.kdeplot(data=err, ax=ax)
legend=ax.legend()
legend.remove()
ax.set_title("Distribución de error en datos predichos")
ax.set_xlabel("Error")
ax.set_ylabel("Densidad de probabilidad")
ax.set_xlim((-3,3))
ax.set_ylim((0,3))
ax.grid('on', alpha=0.5)
err_mean, err_std=norm.fit(err)
ax.text(-2.8, 1.25, "Centro = "+str(np.round(err_mean, decimals=4))+"\nDesv. Estándar  = "+str(np.round(err_std, decimals=4)), fontsize=11, color="#000")

fig3.suptitle("Resultado de red neuronal (train data="+str(pctg)+"%)")
# Out:
# C:\Users\mcano\AppData\Local\Temp\ipykernel_16740\1787000056.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   full_vec_roi[roi_index[i]]=res[i]
# C:\Users\mcano\AppData\Local\Temp\ipykernel_16740\1787000056.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   full_vec_roi[i]=y.iloc[i]
# C:\Users\mcano\AppData\Local\Temp\ipykernel_16740\1787000056.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   full_vec_cell[cell_index[i]]=res_cell[i]
# C:\Users\mcano\AppData\Local\Temp\ipykernel_16740\1787000056.py:23: RuntimeWarning: divide by zero encountered in divide
#   error_map_r=(abs(np.subtract(y_mat, full_img_cell))/y_mat)*100
# 0.961
# The error map presents 181 error values > 1 (35.98%)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 0.98, 'Resultado de red neuronal (train data=50%)')

# %%
export=0

filename=rf'{name}_linear'
folder=rf'd:\Exports\pres240510'



if export:
    img_export(filename, folder, full_img_roi, full_cell, topography_file, nu_dim)
    histogram_export(full_cell, filename, folder)


export_ref=0

filename=rf'{name}_sim'
folder=rf'd:\Exports\pres240510'

if export_ref: 
    img_export(filename, folder, y_mat, y_cell, topography_file, nu_dim)
    histogram_export(y_cell, filename, folder)

# %%
mapp=list(np.zeros((nu_dim**2)))
train_index_for_full_cell=np.array(cell_index)[train_index]
mapp=[y.iloc[i,0] if i in train_index_for_full_cell else 0 for i in range(len(mapp))]
mapp=np.array(mapp).reshape(nu_dim,nu_dim)

fig=plt.figure(figsize=(24,4))
ax=fig.add_subplot(1,4,1)
ax.imshow(np.rot90(T_mat), cmap='afmhot')
ax.set_title('Topography')
ax.axis('off')

ax=fig.add_subplot(1,4,2)
pcm=ax.imshow(np.rot90(mapp), cmap=newcmp, vmin=0, vmax=20)
ax.set_title(f'Training data points ({pctg}% of ROI)')
ax.axis('off')
plt.colorbar(pcm, label=f'$ε_p$')

ax=fig.add_subplot(1,4,3)
pcm=ax.imshow(np.rot90(full_img_roi), vmin=1, vmax=20)
ax.set_title('Neural network prediction')
ax.axis('off')
plt.colorbar(pcm, label=f'$ε_p$')

ax=fig.add_subplot(1,4,4)

ax.hist(y_cell, histtype="step", color="#000",bins=binss)
ax.hist(res_cell, histtype="bar", color="#92def7",bins=binss)
ax.set_xticks(xaxis)
ax.set_xlim([1,np.max(binss)])
ax.set_ylim([0,40])
ax.set_title("Histogram comparison")
ax.legend(["Original","Prediction \n(train data="+str(pctg)+"%)"])
ax.set_xlabel("$ε_{p}$")
ax.set_ylabel("Count")
ax.grid('on', linestyle=':', alpha=0.7)
ax.minorticks_on()
